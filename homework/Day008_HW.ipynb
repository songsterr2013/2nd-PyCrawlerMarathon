# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ##  1.Request 取回之後該怎麼取出資料，資料型態是什麼？
#
# Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36'}
res = requests.get('https://www.dcard.tw/f',headers=headers)

res_=res.content.decode('utf-8')
res_
# Out:
# '<!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n      j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n      \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\',\'GTM-TWLTW4M\');</script><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta charSet="utf-8"/><meta name="description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:type" content="website"/><meta property="twitter:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta name="image" itemProp="image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image:secur ...

# %% [markdown]
# #### 知乎： https://www.zhihu.com/explore

# %%
headers = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36'}
res2 = requests.get('https://www.zhihu.com/explore',headers=headers)

res_2=res2.content.decode('utf-8')
res_2
# Out:
# '<!DOCTYPE html>\n<html lang="zh-CN" dropEffect="none" class="no-js no-auth ">\n<head>\n<meta charset="utf-8" />\n\n<meta http-equiv="X-ZA-Experiment" content="default:None">\n<title>发现 - 知乎</title>\n\n<meta name="apple-itunes-app" content="app-id=432274380, app-argument=zhihu://explore">\n\n\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>\n<meta http-equiv="mobile-agent" content="format=html5;url=https://www.zhihu.com/explore">\n<meta id="znonce" name="znonce" content="1e11f9fbd76f425f9603b596e958ba00">\n\n\n\n<link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-152.87c020b9.png" sizes="152x152">\n<link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-120.496c913b.png" sizes="120x120">\n<link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-76.dcf79352.png" sizes="76x76">\n<link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-60.9911cffb.png" sizes="60x60">\n\n\n<link rel="shortcut icon" href="https://static.zhihu.com/static/favicon.ico" type="image/x-icon">\n\n<link rel="search" type="application/opensearchdescription+xml" href="https://static.zhihu.com/static/search.xml" title="知乎" />\n\n\n<link rel="stylesheet" href="https://static.zhihu.com/static/revved/-/css/m.7c4d48ad.css">\n\n<meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" />\n\n\n\n<!--[if lt IE 9]>\n<script src="https://static.zhihu.com/static/components/respond/dest/respond.min.js"></script>\n<link href="https://static.zhihu.com/static/components/respond/cross-domain/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />\n<link href="/static/components/respond/cross-domain/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />\n<script src="/static/components/respond/cross-domain/respond.proxy.js"></script>\n<![endif]-->\n<script src="https://static.zhihu.com/static/revved/-/js/instant.35b468b8.js"></script>\n\n</head>\n\n<body class="zhi page-explore">\n\n\n\n\n<div role="navigation" class="zu-top" data-za-module="TopNavBar">\n<div class="zg-wrap modal-shifting clearfix" id="zh-top-inner">\n<a href="/" class="zu-top-link-logo" id="zh-top-link-logo" data-za-c="view_home" data-za-a="visit_home" data-za-l="top_navigation_zhihu_logo">知乎</a>\n\n\n\n<ul class="topnav-noauth clearfix">\n\n<li>\n<span class="top-btn-inner-shdw"></span><span class="top-btn-sep"></span>\n</li>\n<li>\n<a href="javascript:;" class="js-signup-noauth-mobile">\n<span class="top-btn-inner-shdw left"></span>\n注册\n<span class="top-btn-inner-shdw right"></span>\n</a>\n</li>\n<li>\n<span class="top-btn-sep"></span>\n</li>\n<li>\n<a href="javascript:;" class="js-signin-noauth-mobile">\n<span class="top-btn-inner-shdw left"></span>\n登录\n<span class="top-btn-inner-shdw right"></span>\n</a>\n</li>\n\n\n<li>\n\n<span class="top-btn-sep"></span>\n\n</li>\n<li>\n<a href="#" id="js-openInApp">\n<span class="top-btn-inner-shdw left"></span>\n<i class="zg-icon zg-icon-cell"></i>打开 App\n</a>\n</li>\n\n</ul>\n\n\n\n\n\n\n</div>\n</div>\n\n\n<div class="zu-global-notify" id="zh-global-message" style="display:none">\n<div class="zg-wrap">\n<div class="zu-global-nitify-inner">\n<a class="zu-global-notify-close" href="javascript:;" title="关闭" name="close">x</a>\n<span class="zu-global-notify-icon"></span>\n<span class="zu-global-notify-msg"></span>\n</div>\n</div>\n</div>\n\n\n\n\n<div class="zg-wrap zu-main clearfix "  role="main">\n<div class="zu-main-content">\n<div class="zu-main-content-inner">\n\n\n\n\n\n<div id="zh-recommend">\n<div id="zh-recommend-title" class="page-title">\n<i class="zg-icon zg-icon-feedlist"></i>\n<span>编辑推荐</span>\n<a href="/explore/recommendations" class="zg-link-gray zg-right" data-za-c="explore" data-za-a="visit_explore_recommendations" data-za-l="editor_recommendations_more"><span>更多推荐 &raquo;</span></a>\n</div>\n<div id="zh-recom ...

# %% [markdown]
# ### 資料型態是什麼？

# %%
print('「Dcard」資料型態為:',type(res_))
print('「知乎」資料型態為:',type(res_2))
# Out:
# 「Dcard」資料型態為: <class 'str'>
# 「知乎」資料型態為: <class 'str'>

# %% [markdown]
# # ===================================

# %% [markdown]
# ## 2.為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？

# %% [markdown]
# #### Dcard

# %%
# soup.prettify()可以美化排版
soup = BeautifulSoup(res_,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
#   <meta content="com.sparkslab.dcardreader" property="al:android:package"/>
#   <meta content="Dcard" property="al:android:app_name"/>
#   <link href="/_next/static/manifest.json" rel="manifest"/>
#   <link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/>
#   <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
#   <link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#   <link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
#   <link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#   <link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
#   <link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
#   <link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
#   <link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
#   <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');
#   </script>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/>
#   <meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/>
#   <title>
#    全部 | Dcard
#   </title>
#   <link href="https://www.dcard.tw/f/all" rel="canonical"/>
#   <meta content="https://www.dcard.tw/f?hyper-version=true" itemprop="url" name="url"/>
#   <meta content="Dcard" property="og:site_name"/>
#   <meta content="全部 | Dcard" property="og:title"/>
#   <meta content="https://www.dcard.tw/f?hyper-version=true" property="og:url"/>
#   <meta content="全部 | Dcard" property="twitter:title"/>
#   <meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/>
#   <meta content="dcard://category" property="al:ios:url"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"CollectionPage","name":"全部","url":"https://www.dcard.tw/f/all","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f/all"}]}
#   </script>
#   <meta content="21" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/>
#   <link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/>
#   <link as="script" href="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/forum.js" rel="preload"/>
#   <link as="script" href="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/_app.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.a7927da712c2b615dfc7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/594bfe24906a2ede671370e37681d9c23b5e51d0.dbf2953254398f42164a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b25bcdb1e7ba05b12936d4c250bc53fdddb47360.7693a06c8d147e1bd3c6.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b93030b0bbb2a681ce954d756d210dd3b22091cd.973fcdc6f3c8b3c0637e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/88.dc66c05c3d54648ff23c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3c4859d19f00ad0f5d804de5d236492f40221cb1.7cca386140609e544ff4.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/121.010cb2e31f2e19d55b25.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/117.3b6ae08346082b6eeb6e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/122.36fac467ed3d00c822e2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/df0946cb4c0865cc26c76e30ee9a63d7ed2f4911.683e2507bd25f2b774ce.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/80d87c3548640ac7623a7f3e4a7b23b6e2843474.a14f21e81ee4ca85b5a5.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/104.ace3a73d22498f4b5957.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/webpack-b0bf36eede7fd5ee5cfe.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework.b347b462804689eaf927.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.a7927da712c2b615dfc7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/594bfe24906a2ede671370e37681d9c23b5e51d0.dbf2953254398f42164a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b25bcdb1e7ba05b12936d4c250bc53fdddb47360.7693a06c8d147e1bd3c6.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b777109c05c1680f5141243e7355faf68105634d.a3ea63189e554c385099.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/fd9e4387cac53e3e01237a32ef8edb7c5ba4b868.d5dfc3ae04ba5cb3723e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7359311a9d01ecba33641507c4f214be45e0106f.279ba96673904ae6e30c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b8d4382911fe490512a63d22ba2c08a046a34ef7.f163dec2906e5e0593a6.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/af326e5a2f24698a224ae59a0aa08ee75ac93aee.01f83f8c6bc436062955.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6ed2ac0cfb28e2327638daeda163ae54e78a01ba.7100a99d0af72d20cd4a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1f72ddc651f45282f9ccda39c7a63e5016539931.a0bb8772ba363a189a37.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/2b8f6092e5f61fd3f7d20d35dae48f870ad9cfd4.2f1e8487244c4c0bef7c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/9d907c18bbce1d8acda0eef070c9abff7334ab9f.754feaca83ad4aebe852.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/main-a7f9ee31f9bcb2fc7fc0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7fa1ca47aca8ca1ec92bd86b0ce2561f39113bd6.cfe5dcd104c88ccb7266.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/b93030b0bbb2a681ce954d756d210dd3b22091cd.973fcdc6f3c8b3c0637e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/462f53e82956e978ffc7b9950012c598b58e8cd4.cff47e2afb4b09e017dd.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5ddffa3dcce25ac4eaa0d0b27025a332703dd129.0b621bd9b2b3e8b2d105.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/df0946cb4c0865cc26c76e30ee9a63d7ed2f4911.683e2507bd25f2b774ce.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/61b6311446725977a3716362d8e1c720eb271b31.9dd764b668b1cc4807a1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/4079e89bf8ad6cb3c163afff3c8c5cabdbcb8914.41e27a9820e813260c8f.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/9f9d47bd318278b5f5032af054ffe9a1700e141c.f92a8f7fad2a2b7ea71e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/802b68d0d506bda42b98b2d01ae1fa07f5397ec9.89d48e6ab9ba067e9295.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/040f993490df8b4fbe225032a4f3be0be652010c.f2f3e1935c62763d9450.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/adf8d61cc41c535085045c051aea94432dc5f602.330f71984aec0e90a2b7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/311537684536954336b90497a89d9e6866c0da94.06aab674237ef3df95d6.js" rel="preload"/>
#   <style data-styled="bUmARS gRRqRb bkKJCY jsnIlX bIaPwJ gYUaPZ DLzzZ ierzKU dODGjA fWARvU bkAvTt kUMklR jMlptb etwaaz hhSnba gCQlMD iYfIzd jkPESf cbhXy iUPhXV bwTNRH eBsKJJ gRIdVl ieFmwo joALQw iLWWtS bVLqqa ghaHAR fOPJtW ThNwj dSUmAI iMiymk dcqUEg jpMqdZ hUzwID jNpFNp gRbPUS iRqRiV hKhxmR dxnOXH hsLXWk bpRtvu kOrqkD hJMFCR hItsgT kXMWcz cFXnvT huoxoU etJJNt gigzWd dUbrTF iemAGN jJGxwk eNbBFe pwVHE fnZGBW deAgGq hBSEpL kHkpXF fxrSjZ iNRVSl eFRAge fbSOZM hxnDlf hHcDde hkMYqq jCnppg jECWhv cyxnyd gFeWgh jAlbWa kgcVsA kUHSsi kGxGfT iIxOaU SyCyI fXqGIR bcPQqz eSJmXu fxUbNa dlKdBb cuooPm gxMzaW gbMrPL iTmOcw hraxjl eZbqml lcIqKn dLkKRc eqvIEe btuVdm kckiFT iqLTew eJidNy fVjALD jcFMFq ebZjiw IUuAe bzukiT cZtAnP dzTxyj hZgYmk iaivJq hQwPvQ ciNPhh hpsGZq iJCqeQ kqKnyl nlkop isaDQa erAJaE RXydf OILQi kZCsFy betuvQ iIAXov czskAd dfMeMY bMcWeV iQOEbz iYoAav gpDnCL caWTMK jOcHHK cJCjqJ bcJcFo gHmUSp buQRlc iGtQjR eJUhfX hzTqOV dYEYmA hxUnBd XuWwf flRoDA dTLUmr hldKBV jXIcFN jKdblb dkyZPk kkMFCl cMiHcM Gmrxn cRztcx jMCMEQ kixOiI eEHQqz hXxAcg bYEzsx jMfoLl hlMSPR jlrtwS gQppLy ysVLI jMLLks EwkGw jrlgGO gxfQHx itqZIx fEehkS eIziSL ivZWVt fqZlER cBnrmc hZFMwL bIpmBg ckDVtE jqQjXw djONzs eAhnbu ghqLuf OwCkg ncfED dlPWaY BwuPj byxsrh dSegVb bRnEby ecjfiK bSsANV ivDbZc cFiVjn dcNdrk depmhf gNGRiu iuwwGB cpTBpt LOoxt kKGpPU dAoIED gsHlVd hazOCN Jfeif kNRXii fckXqK eesaVQ eSmJFM isnJWr ggghhN eTULnC ihANtq vDKIy kTnPum jEVzWj cuEcOa bsYdqe gdmrGU kMCYaU hmvoFh dyRjoS fAWpiS eFJVVU kDfHlX iitPqz fpNVYd cecgEa imwAVu kVAWGS byDBmK jQdHiY TPgVx bdyeVL bBfeqi kjEfMP ePHxKd cYhtHG emCoUh dWsFia jzyqCw plPAm jxylh gbKHmK cCroaN fCbVDL fRNXlA fQRmbe hXKZaE fSCGBE iNyOec bjRUSj gGMWCL bidfJM kJDoqS ilfjSQ hVgWEJ dPikPc dlgmsZ jiHLSv jEZPjy bTmkgy ggDfwf faOGPM dZAyTv eovMJg biuOgX fIIbis kIHllc kuHcDT jJQpBM insmFI eVlkqk cwISxR diKdXk kRpKVC dMeoYj hAJthG iJUolo kEqbwG bEjGJ hwZyUa hSVvaC kYQETz sNXpc bdiPqF iiuJxt bpFdYQ kwKhDZ ckQNRs cgJBak ixRRBn gvAXQd dsnHsN liSdyl jrxZUr dqWqzv lhsczA dIRWqE iFAYXP cQLDGK bdZmTC iKgfXR bWuoYI llXfXW ivbvQc hXoZkZ kbkhkz hjiaRP iylEpa jqeVLP BbchW chxBzh embxsz evXCTK jZUqpg eCXIkK gLgozE dCFyQz bSDwXy ffqrHf fYHPhX buwgzc hbaYDn hAyDgJ fPjsad iVFhUp dLdNOh eiVDLb ldnNRb ehIwJk bbkFRh iPfgRb fnlfmy lbsLUN jNSdZG kuUoxV hFiaOa hVlCDH lLnjb gLRgot cDOlbF jzwjYE bvlcaJ cuCQeX hTuwCj fhXqpM gLtzjK bTNwXs droeny hbEBdw evkaJd cndvyl dqflxk cPscHp jaanNY bxXvuf ihOAVM ipNzEb jXUbWR koLFZq eaLDLa eMTQDH bdKxaG ghGlyV XVOjy iPvxPT gXeATs heuwav fNGJuR gpeOcj LDAeQ iqJaVy jIVHRC bOYByu bjdYUu dOkRgV hwdXcL jNwtlj iOzsDO iGmKuW WvYkQ ljzkes ghNSwV jkGRpF fJtwvR fGQIDA jtvXJG loGrpV dSfSZj hNFeaU hCORjC jucutm iKKITa kzfyvZ dNlAQx byYWgy ksBdyw hIxRsU cKqvpZ jbTEXW gmXegT hjUALt kfUocV hFDKYk uMqVT ejGGcN fPUdMX eEyDXr hZgEVT gMdOpQ kBuUGm eIfGGG ZMTGu kxkNtK gICjbS hXfVSM kAoXjI gSAyIA kOuKtY euMuXn kHWxpe gcmexk hVbCyk kxyubO fqwYqb gweLWu erNmSp ceTQbG dWIUpW gyqGVr kEGMCC eZdTFS bvJPeQ dnMqPh hJPCtc jYCpdS ipEvtw iIWtTd ekONGB gBKTwh gqgmhE jVNDlw cKXprA laidyT dnXWWU fcxNa bCYHki dcenFv iRsbpo cKxCNV dVDdAA bbccHi gROhmZ jeQInQ iABrDZ Tnyys nPcXo gEOBcE cyTJni dOjssS keNDr ebeETo egysnz bnmAuK jOLwdE ckKIBS hhdWwc eDOnQF Lleku fQzSqc feEikY fpliGk fMTeMY dHcciZ jVdrCl jiGuKx gFYAcC bRrbVo fKRBfF bgyDTM gYyepm hMosRF jkYPE jcNoGh hpVMDA jvmYKq hbkYFv gNrDWj hXuOLo dcoFBG ixCfyj cUVfBO gmVqEd gHcQxw kGNRhO ewfjeH ihedFC dieVrp fbthWw dYgxrm fxJymq fovpBr bqsyGi cdRLsd jqcJsA ldigww leIhQz dwPZzI dMzLpW gqEuKy pSqZd iswJRs nxpdZ iKYjHR ctaOPb iNrhYe jSLiLv cvhyVb hskUee cmjkHd gvsHgZ dkztMQ eOqpTD kFayiE bmbkUO inlQlR jnOTkv iOjPQv cKalRz fACrXg dKebJG dGliJV fJjvoY bReBxG etevno cKmYJf ejhEQx gpKohw kejNvk htVlD daiIpF bZgmbl lgWNNn duhhIF gFxUyu eQGOlH iFCZNH jntCkB hjRROS jOpoAq kdlwoh eJGwQY jrtXBR ghccAs cKxtrZ dykAcs feAVOA gWtdfB ogdUz eSWhfz Fzfdz hUVsj gHZDSU gYXlWv eTxtzv bNRMtc aEXNq hPNbBN fMLUtJ jyJcRR dMamAs glQxpi dOyvWD eSChfC bTcUk cAUXkt dagORX fIvJvb dARMVx dGuoO hSudgn qyGOB irssaW jXGXYv pgBqI jUeWjN i ...
#    /* sc-component-id: sc-global-1522344194 */
# body{background-color:#eee;}
# /* sc-component-id: ksi2hf-0 */
# .eNbBFe{display:none;}
# /* sc-component-id: ydgdj7-0 */
# .hhSnba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hhSnba img,.hhSnba svg{height:100%;width:100%;}.gCQlMD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gCQlMD img,.gCQlMD svg{height:100%;width:100%;}.iYfIzd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iYfIzd img,.iYfIzd svg{height:100%;width:100%;}.jkPESf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jkPESf img,.jkPESf svg{height:100%;width:100%;}.cbhXy{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cbhXy img,.cbhXy svg{height:100%;width:100%;}.iUPhXV{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iUPhXV img,.iUPhXV svg{height:100%;width:100%;}.bwTNRH{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bwTNRH img,.bwTNRH svg{height:100%;width:100%;}.eBsKJJ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .eBsKJJ img,.eBsKJJ svg{height:100%;width:100%;}.gRIdVl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gRIdVl img,.gRIdVl svg{height:100%;width:100%;}.ieFmwo{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .ieFmwo img,.ieFmwo svg{height:100%;width:100%;}.joALQw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .joALQw img,.joALQw svg{height:100%;width:100%;}.iLWWtS{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}  ...
# /* sc-component-id: sc-1ag928-0 */
# .kUMklR{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;outline:none;font-size:16px;line-height:normal;border-radius:4px;padding:0 10px;height:40px;width:100%;-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);border:1px solid rgba(0,0,0,0.25);} .kUMklR::-webkit-input-placeholder{color:#c1c2c5;} .kUMklR::-moz-placeholder{color:#c1c2c5;} .kUMklR:-ms-input-placeholder{color:#c1c2c5;} .kUMklR::placeholder{color:#c1c2c5;}
# /* sc-component-id: pw4e6a-0 */
# .ierzKU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .ierzKU form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.dODGjA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .dODGjA form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:rgb(238,238,238);border-radius:4px;overflow:hidden;width:100%;}
# /* sc-component-id: pw4e6a-1 */
# .fWARvU{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:14px;color:#fff;}.bkAvTt{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:16px;}
# /* sc-component-id: pw4e6a-2 */
# .jMlptb{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: pw4e6a-3 */
# .elZfHj{padding-left:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: pw4e6a-4 */
# .copHwd{padding:0 2px;}
# /* sc-component-id: sc-1divb7s-0 */
# .jGSaFz{position:-webkit-sticky;position:sticky;top:48px;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}.kkFyqs{position:-webkit-sticky;position:sticky;top:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}
# /* sc-component-id: sc-1divb7s-1 */
# .jgHqud{padding-top:10px;}
# /* sc-component-id: sc-1divb7s-2 */
# .fvImY{height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1divb7s-3 */
# .jqcDIF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1divb7s-4 */
# .iXnhSl{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iXnhSl:first-child{padding-left:0;} .iXnhSl a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .iXnhSl a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.glFNEP{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .glFNEP:first-child{padding-left:0;} .glFNEP a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .glFNEP a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.eOmoiY{height:100%;white-space:nowrap;} .eOmoiY:first-child{padding-left:0;} .eOmoiY a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .eOmoiY a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.kQMWIM{height:100%;white-space:nowrap;} .kQMWIM:first-child{padding-left:0;} .kQMWIM a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .kQMWIM a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: r0dumd-0 */
# .hraxjl{position:fixed;top:60px;right:25px;z-index:1000;}.eZbqml{position:fixed;bottom:33px;left:50%;right:50%;width:100vw;z-index:1000;}
# /* sc-component-id: sc-84v443-0 */
# .jAlbWa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .jAlbWa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .jAlbWa:hover{background:#006aa6;}.kgcVsA{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .kgcVsA:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kUHSsi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #c1c2c5;background:#fff;color:rgba(0,0,0,.6);} .kUHSsi:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .kUHSsi:hover{background:#efefef;} .kUHSsi:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.kGxGfT{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .kGxGfT:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.iIxOaU{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .iIxOaU:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .iIxOaU:hover{background:#006aa6;}.SyCyI{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:transparent;color:rgba(0,0,0,.6);-webkit-text-decoration:underline;text-decoration:underline;} .SyCyI:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .SyCyI:active{box-shadow:none;}.fXqGIR{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #3397cf;color:#006aa6;background:#fff;} .fXqGIR:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .fXqGIR:hover{background:#efefe ...
# /* sc-component-id: sc-84v443-2 */
# .jnmJtt> button{border-radius:0;} .jnmJtt>*:first-child{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:first-child button{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:last-child{border-radius:0 4px 4px 0;border-left-width:0;} .jnmJtt>*:last-child button{border-radius:0 4px 4px 0;border-left-width:0;}
# /* sc-component-id: sc-1y4sp2u-0 */
# .hHcDde{text-align:center;color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;}
# /* sc-component-id: sc-1y4sp2u-1 */
# .cyxnyd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: sc-1y4sp2u-2 */
# .fAGnSD{color:rgba(0,0,0,.85);font-size:17px;font-weight:500;margin-bottom:24px;}
# /* sc-component-id: sc-1y4sp2u-3 */
# .hkMYqq{height:120px;margin-bottom:20px;}
# /* sc-component-id: sc-1y4sp2u-4 */
# .jCnppg{color:rgba(0,0,0,.6);font-size:17px;font-weight:500;margin-bottom:10px;}
# /* sc-component-id: sc-1y4sp2u-5 */
# .jECWhv{color:rgba(0,0,0,.35);}
# /* sc-component-id: kzwdbj-0 */
# .fbSOZM{background-color:#fff;position:relative;height:100vh;width:100%;padding-top:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .fbSOZM img{height:180px;}.hxnDlf{background-color:#fff;position:relative;height:100vh;width:100%;padding-top:0px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .hxnDlf img{height:180px;}
# /* sc-component-id: kzwdbj-1 */
# .gFeWgh{margin-top:20px;}
# /* sc-component-id: sc-1ot278l-0 */
# .cwISxR{height:76px;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;border-bottom:1px solid #d9d9d9;background-color:#fff;}
# /* sc-component-id: sc-1ot278l-1 */
# .diKdXk{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ot278l-2 */
# .kRpKVC{width:44px;height:44px;}
# /* sc-component-id: sc-1ot278l-3 */
# .dMeoYj{margin-left:16px;}
# /* sc-component-id: sc-1ot278l-4 */
# .hAJthG{margin:0;color:rgba(0,0,0,0.75);font-size:17px;}
# /* sc-component-id: sc-1ot278l-5 */
# .iJUolo{margin:8px 0 0;color:rgba(0,0,0,0.5);font-size:13px;}
# /* sc-component-id: u7yy6z-0 */
# .fnZGBW{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}.deAgGq{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}.hBSEpL{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;padding:0 12px;}.kHkpXF{background-color:#00588a;width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}
# /* sc-component-id: u7yy6z-1 */
# .fxrSjZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}
# /* sc-component-id: z145e7-0 */
# .jSLiLv{cursor:pointer;fill:rgba(0,0,0,0.2);}.cvhyVb{cursor:pointer;fill:#3397cf;}
# /* sc-component-id: fhv42m-0 */
# .LOoxt{width:64px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;}.kKGpPU{width:56px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;}.dAoIED{width:64px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;color:rgba(0,0,0,0.75);background-color:rgba(0,16,32,0.06);} .dAoIED:hover{background-color:rgba(0,0,0,.2);}.gsHlVd{width:56px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;width:70px;color:rgba(0,0,0,0.75);background-color:rgba(0,16,32,0.06);}
# /* sc-component-id: o9lczm-0 */
# .dcNdrk{display:block;border-radius:50%;object-fit:cover;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;overflow:hidden;}
# /* sc-component-id: cagncm-0 */
# .heuwav{position:relative;}
# /* sc-component-id: cagncm-1 */
# .LDAeQ{visibility:hidden;padding-top:calc(100% / 1.7777777777777777);pointer-events:none;}.iqJaVy{visibility:hidden;padding-top:calc(100% / 2.111111111111111);pointer-events:none;}.jIVHRC{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}.bOYByu{visibility:hidden;padding-top:calc(100% / 0.5625);pointer-events:none;}.bjdYUu{visibility:hidden;padding-top:calc(100% / 0.5624999999999993);pointer-events:none;}.dOkRgV{visibility:hidden;padding-top:calc(100% / 1.3333333333333333);pointer-events:none;}.hwdXcL{visibility:hidden;padding-top:calc(100% / 1.8181818181818181);pointer-events:none;}.jNwtlj{visibility:hidden;padding-top:calc(100% / 0.75);pointer-events:none;}.iOzsDO{visibility:hidden;padding-top:calc(100% / 1.775);pointer-events:none;}.iGmKuW{visibility:hidden;padding-top:calc(100% / 1.7733990147783252);pointer-events:none;}.WvYkQ{visibility:hidden;padding-top:calc(100% / 0.5678233438485805);pointer-events:none;}.ljzkes{visibility:hidden;padding-top:calc(100% / 1.791044776119403);pointer-events:none;}.ghNSwV{visibility:hidden;padding-top:calc(100% / 1.4592592592592595);pointer-events:none;}.jkGRpF{visibility:hidden;padding-top:calc(100% / 0.8);pointer-events:none;}.fJtwvR{visibility:hidden;padding-top:calc(100% / 0.5660377358490566);pointer-events:none;}.fGQIDA{visibility:hidden;padding-top:calc(100% / 0.6091370558375635);pointer-events:none;}.jtvXJG{visibility:hidden;padding-top:calc(100% / 0.5324459234608985);pointer-events:none;}.loGrpV{visibility:hidden;padding-top:calc(100% / 0.5593750000000001);pointer-events:none;}.dSfSZj{visibility:hidden;padding-top:calc(100% / 0.5611111111111111);pointer-events:none;}.hNFeaU{visibility:hidden;padding-top:calc(100% / 0.4591836734693878);pointer-events:none;}.hCORjC{visibility:hidden;padding-top:calc(100% / 0.81875);pointer-events:none;}.jucutm{visibility:hidden;padding-top:calc(100% / 0.5042016806722689);pointer-events:none;}.iKKITa{visibility:hidden;padding-top:calc(100% / 1.5);pointer-events:none;}.kzfyvZ{visibility:hidden;padding-top:calc(100% / 2.162162162162162);pointer-events:none;}.dNlAQx{visibility:hidden;padding-top:calc(100% / 2.1666666666666665);pointer-events:none;}.byYWgy{visibility:hidden;padding-top:calc(100% / 1.0596026490066226);pointer-events:none;}.ksBdyw{visibility:hidden;padding-top:calc(100% / 5);pointer-events:none;}.hIxRsU{visibility:hidden;padding-top:calc(100% / 0.6081081081081081);pointer-events:none;}.cKqvpZ{visibility:hidden;padding-top:calc(100% / 1.0777777777777777);pointer-events:none;}.jbTEXW{visibility:hidden;padding-top:calc(100% / 0.45454545454545453);pointer-events:none;}.gmXegT{visibility:hidden;padding-top:calc(100% / 1.1678832116788322);pointer-events:none;}.hjUALt{visibility:hidden;padding-top:calc(100% / 0.46249999999999997);pointer-events:none;}.kfUocV{visibility:hidden;padding-top:calc(100% / 0.7);pointer-events:none;}.hFDKYk{visibility:hidden;padding-top:calc(100% / 3);pointer-events:none;}.uMqVT{visibility:hidden;padding-top:calc(100% / 1.761111111111111);pointer-events:none;}.ejGGcN{visibility:hidden;padding-top:calc(100% / 1.787709497206704);pointer-events:none;}.fPUdMX{visibility:hidden;padding-top:calc(100% / 0.8624999999999999);pointer-events:none;}.eEyDXr{visibility:hidden;padding-top:calc(100% / 1.2583333333333333);pointer-events:none;}.hZgEVT{visibility:hidden;padding-top:calc(100% / 1.7647058823529411);pointer-events:none;}.gMdOpQ{visibility:hidden;padding-top:calc(100% / 2.0666666666666664);pointer-events:none;}.kBuUGm{visibility:hidden;padding-top:calc(100% / 0.56875);pointer-events:none;}.eIfGGG{visibility:hidden;padding-top:calc(100% / 0.487062404870624);pointer-events:none;}.ZMTGu{visibility:hidden;padding-top:calc(100% / 0.562499296875879);pointer-events:none;}.kxkNtK{visibility:hidden;padding-top:calc(100% / 1.702127659574468);pointer-events:none;}.gICjbS{visibility:hidden;padding-top:calc(100% / 0.4864864864864865);pointer-events:none;}.hXfVSM{visibility:hidden;padding-top:calc(100% / 0.73125);pointer-event ...
# /* sc-component-id: cagncm-2 */
# .fNGJuR{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: thjnss-0 */
# .hwZyUa{margin-right:16px;}
# /* sc-component-id: sc-1ywcn7k-0 */
# .gYUaPZ{display:block;height:100%;}
# /* sc-component-id: lvor8b-0 */
# .jsnIlX{height:100%;padding:16px 0;display:block;}.bIaPwJ{height:100%;padding:10px 0;display:block;}
# /* sc-component-id: sc-16ejmvj-0 */
# .jYRLDW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-shadow:0px 0px 1px rgba(0,0,0,.35);padding:12px 16px;border-bottom:1px solid rgba(0,0,0,0.05);width:100%;background-color:rgb(250,250,250);}
# /* sc-component-id: sc-16ejmvj-1 */
# .glYNav{-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.35);font-size:15px;font-weight:bold;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-16ejmvj-2 */
# .dMbzLL{cursor:pointer;fill:rgba(0,0,0,.35);}
# /* sc-component-id: wswqpf-0 */
# .ebZjiw{position:relative;width:100%;height:100%;}
# /* sc-component-id: wswqpf-1 */
# .IUuAe{position:absolute;top:0;left:0;bottom:0;right:0;}
# /* sc-component-id: wswqpf-3 */
# .cZtAnP{box-sizing:border-box;}
# /* sc-component-id: wswqpf-5 */
# .iaivJq{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);left:0;bottom:0;height:var(--track-size);width:100%;} .iaivJq:hover{background-color:rgba(0,0,0,0.3);}
# /* sc-component-id: wswqpf-6 */
# .dzTxyj{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);width:var(--track-size);height:100%;top:0;right:0;} .dzTxyj:hover{background-color:rgba(0,0,0,0.3);}
# /* sc-component-id: wswqpf-8 */
# .hQwPvQ{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);height:var(--thumb-size);margin:var(--thumb-margin) 0;} .wswqpf-0:hover .hQwPvQ{opacity:1;} .wswqpf-4:hover .hQwPvQ{height:var(--track-size);margin:0;}
# /* sc-component-id: wswqpf-9 */
# .hZgYmk{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);width:var(--thumb-size);margin:0 var(--thumb-margin);} .wswqpf-0:hover .hZgYmk{opacity:1;} .wswqpf-4:hover .hZgYmk{width:var(--track-size);margin:0;}
# /* sc-component-id: sc-9l1ap-0 */
# .kEUYKq{width:100%;}
# /* sc-component-id: sc-1g7qmex-0 */
# .ivpUrR{background-color:#fff;}
# /* sc-component-id: sc-1g7qmex-1 */
# .gIZWdO{padding:16px;}
# /* sc-component-id: sc-1ykc0nb-2 */
# .iNRVSl{display:inline-block;height:100%;}
# /* sc-component-id: sc-1bxk7up-0 */
# .iKYjHR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:400px;height:500px;}
# /* sc-component-id: sc-1tl0s6i-0 */
# .gRRqRb{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1tl0s6i-1 */
# .bkKJCY{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1tl0s6i-2 */
# .pwVHE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}
# /* sc-component-id: dvujgj-0 */
# .kEqbwG{height:48px;width:100%;background:#006aa6;}
# /* sc-component-id: dvujgj-1 */
# .bEjGJ{max-width:px;height:100%;margin:auto;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:4px;}
# /* sc-component-id: vvoj3g-0 */
# .iPvxPT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 12px;} .iPvxPT::after{content:'';display:none;position:absolute;top:0;right:0;-webkit-transform:translate(50%,-50%);-ms-transform:translate(50%,-50%);transform:translate(50%,-50%);width:4px;height:4px;padding:0;border:7px solid #ea5c5c;border-radius:100px;box-shadow:0 2px 4px 0 rgba(0,0,0,0.2);background:#fff;}
# /* sc-component-id: vvoj3g-1 */
# .nxpdZ{margin-right:8px;}
# /* sc-component-id: sc-15zy2le-0 */
# .bUmARS{position:fixed;top:0;z-index:11;height:60px;width:100%;background:#006aa6;}
# /* sc-component-id: sc-15zy2le-1 */
# .DLzzZ{padding:0 20px;max-width:432px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-16h2w5-1 */
# .gjAJJD.gjAJJD{padding:40px 80px;}
# /* sc-component-id: jo1zdl-0 */
# .hzaMZS{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:300px;max-width:calc(100vw - 48px);min-height:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}.rCmLK{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:90%;max-width:calc(100vw - 48px);min-height:0;max-height:calc(100% - 48px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}.jLjFsr{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:300px;max-width:calc(100vw - 48px);min-height:0;max-height:calc(100% - 48px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}
# /* sc-component-id: jo1zdl-1 */
# .dJUxnG{padding:24px 24px 10px;}.fYWvDg{padding:40px 40px 10px;}
# /* sc-component-id: jo1zdl-2 */
# .cTNmGN{position:relative;}
# /* sc-component-id: jo1zdl-3 */
# .iMYeMt{font-size:24px;font-size:20px;font-weight:700;line-height:24px;color:rgba(0,0,0,.85);text-align:left;}.bZFzBN{font-size:24px;font-weight:700;line-height:24px;color:rgba(0,0,0,.85);text-align:left;}
# /* sc-component-id: jo1zdl-4 */
# .keinQf{padding:0 24px;color:rgba(0,0,0,.8);font-size:13px;line-height:1.4;}
# /* sc-component-id: jo1zdl-7 */
# .kzOwDl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;overflow-y:auto;min-height:0;} .kzOwDl:nth-child(2) > div{padding-top:0;}
# /* sc-component-id: jo1zdl-8 */
# .ifDwvY{-webkit-flex:1;-ms-flex:1;flex:1;height:100%;padding:20px 24px 24px;}.dUMZtU{-webkit-flex:1;-ms-flex:1;flex:1;height:100%;padding:20px 40px 40px;}
# /* sc-component-id: sc-8dk2q5-1 */
# .iCflnd{min-height:0;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-8dk2q5-2 */
# .gpTxIH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:20px;} .gpTxIH:first-child{margin-top:0;}
# /* sc-component-id: sc-8dk2q5-3 */
# .cuDCyD{margin-left:20px;} .cuDCyD:first-child{margin-left:0;width:100%;}.iGgriV{margin-left:20px;} .iGgriV:first-child{margin-left:0;}
# /* sc-component-id: sc-1o8g0c8-0 */
# .ilKREK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}
# /* sc-component-id: sc-1o8g0c8-1 */
# .gBtEqF{display:none;}
# /* sc-component-id: sc-1o8g0c8-2 */
# .caoQNx{position:relative;height:18px;width:18px;border-radius:15%;border:1px solid rgba(0,0,0,0.15);margin-right:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;} .caoQNx:after{position:absolute;display:block;box-sizing:border-box;content:'';top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);height:75%;width:75%;border-radius:15%;visibility:visible;-webkit-transition:background-color 0.15s cubic-bezier(.4,0,.2,1);transition:background-color 0.15s cubic-bezier(.4,0,.2,1);cursor:pointer;}
# /* sc-component-id: uzae24-0 */
# .eSWhfz{width:100%;height:100%;position:relative;background:#000;}
# /* sc-component-id: uzae24-1 */
# .Fzfdz{position:absolute;top:0;left:0;width:100%;height:100%;}
# /* sc-component-id: cgkbr-0 */
# .dVbdRN{border:0;width:100%;}
# /* sc-component-id: sc-1n5ks60-0 */
# .bLpAcs{background-color:rgb(250,250,250);padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}.ljZaZc{background-color:#fff;padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}
# /* sc-component-id: sc-1n5ks60-1 */
# ...
#                  </path>
#                 </svg>
#                </span>
#               </div>
#               <div class="ulutkk-1 ivbvQc">
#                <span class="ulutkk-2 hXoZkZ">
#                 追星
#                </span>
#                <span class="ulutkk-2 hXoZkZ">
#                 國立臺灣海洋大學
#                </span>
#               </div>
#              </div>
#             </div>
#             <div class="sc-1rp9nay-1 kbkhkz">
#              <h2 class="sc-1rp9nay-3 hjiaRP">
#               <a class="sc-1rp9nay-4 iylEpa" href="/f/entertainer/p/233181879">
#                <span>
#                 因為這篇限動，我更喜歡愛莉莎莎了☺
#                </span>
#               </a>
#              </h2>
#              <div class="sc-1rp9nay-5 BbchW">
#               <span>
#                Youtuber「一隻阿圓」因為去了疫情嚴重的韓國，回台灣不但沒自主隔離，甚至沒戴口罩就出席走鐘獎活動，引起了大家撻伐，當她發現事情的嚴重性後，也立即在個人ig道歉，但大眾媒體似乎不太買單，因為她曾在
#               </span>
#              </div>
#             </div>
#             <div class="sc-1rp9nay-7 chxBzh">
#              <div class="sc-1rp9nay-8 embxsz">
#               <div class="bvzz47-0 jrlgGO">
#                <div class="bvzz47-1 fEehkS" opacity="0.75">
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:3">
#                  <img alt="愛心" src="https://gcs.dcard.tw/reaction/286f599c-f86a-4932-82f0-f5a06f1eca031539599210825.png"/>
#                 </span>
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:2">
#                  <img alt="森77" src="https://gcs.dcard.tw/reaction/aa0d425f-d530-4478-9a77-fe3aedc79eea1539599257655.png"/>
#                 </span>
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:1">
#                  <img alt="哈哈" src="https://gcs.dcard.tw/reaction/e8e6bc5d-41b0-4129-b134-97507523d7ff1539599242687.png"/>
#                 </span>
#                </div>
#                <div class="bvzz47-3 hZFMwL">
#                 4571
#                </div>
#               </div>
#              </div>
#              <div class="sc-1rp9nay-8 embxsz">
#               <span class="sc-1rp9nay-9 evXCTK">
#                回應
#               </span>
#               <span class="sc-1rp9nay-9 evXCTK">
#                212
#               </span>
#              </div>
#             </div>
#             <img alt="" class="x38uc4-0 jOpoAq sc-1rp9nay-12 jZUqpg" height="72px" loading="lazy" src="https://imgur.dcard.tw/S8f3LFSl.jpg" width="72px"/>
#            </article>
#           </div>
#           <div data-index="11">
#            <article class="sc-1rp9nay-0 dIRWqE" data-list-engagement-forum-default="12" role="article">
#             <div class="sc-1rp9nay-2 cQLDGK">
#              <div class="ulutkk-0 bdZmTC">
#               <div class="ulutkk-3 bWuoYI">
#                <span aria-label="男" class="ydgdj7-0 eBsKJJ cra5e8-0 gpDnCL" role="img" size="16">
#                 <svg viewbox="0 0 40 40">
#                  <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#81D4FA">
#                  </path>
#                  <path d="M16 7.9C12.4 7.4 9.3 6 9.3 6s5.5 4.3 5 5.3c-.4 1-4.2 0-4.2 0l4 2a9.7 9.7 0 00-1.5 4.6l.1 3.4a1.5 1.5 0 10.8 2.9 8.3 8.3 0 006.2 5.3c.6 0 .6 2 .6 3.2-1.6 1-2.5 3-2 5v2.2a20.2 20.2 0 009.9-1.6l-.7-2.7v-.4l-.2-.4-.2-.4-.2-.3-.2-.3c-.7-1-1.7-1.6-2.9-1.8l.6-2.3s1.4-1 3-2.6l.4 1.3 1.4-2.5.9-1.8s3.8-10.3.8-13.9c-2.6-3-11-1.9-14.7-2.3" fill="#2490BF">
#                  </path>
#                 </svg>
#                </span>
#               </div>
#               <div class="ulutkk-1 ivbvQc">
#                <span class="ulutkk-2 hXoZkZ">
#                 時事
#                </span>
#                <span class="ulutkk-2 hXoZkZ">
#                 國立屏東大學
#                </span>
#               </div>
#              </div>
#             </div>
#             <div class="sc-1rp9nay-1 kbkhkz">
#              <h2 class="sc-1rp9nay-3 hjiaRP">
#               <a class="sc-1rp9nay-4 iylEpa" href="/f/trending/p/233180522">
#                <span>
#                 📣警公布逃犯照片，有性侵前科📣
#                </span>
#               </a>
#              </h2>
#              <div class="sc-1rp9nay-5 BbchW">
#               <span>
#                台北市大同區一家檳榔攤的女員工，今晨2點多遭53歲男子歐力源持刀恐嚇5000多元；歐隨後駕車開上高速公路往南逃逸，檢警積極追查中。此案獲檢警高度關注，除因歐身分目前為假釋通緝犯、昨晚破壞電子腳鐐逃逸外
#               </span>
#              </div>
#             </div>
#             <div class="sc-1rp9nay-7 chxBzh">
#              <div class="sc-1rp9nay-8 embxsz">
#               <div class="bvzz47-0 jrlgGO">
#                <div class="bvzz47-1 fEehkS" opacity="0.75">
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:3">
#                  <img alt="愛心" src="https://gcs.dcard.tw/reaction/286f599c-f86a-4932-82f0-f5a06f1eca031539599210825.png"/>
#                 </span>
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:2">
#                  <img alt="森77" src="https://gcs.dcard.tw/reaction/aa0d425f-d530-4478-9a77-fe3aedc79eea1539599257655.png"/>
#                 </span>
#                 <span class="ydgdj7-0 gRIdVl bvzz47-2 ivZWVt" size="20" style="z-index:1">
#                  <img alt="驚訝" src="https://gcs.dcard.tw/reaction/4b018f48-e184-445f-adf1-fc8e04ba09b91539675779141.png"/>
#                 </span>
#                </div>
#                <div class="bvzz47-3 hZFMwL">
#                 4289
#                </div>
#               </div>
#              </div>
#              <div class="sc-1rp9nay-8 embxsz">
#               <span class="sc-1rp9nay-9 evXCTK">
#                回應
#               </span>
#               <span class="sc-1rp9nay-9 evXCTK">
#                136
#               </span>
#              </div>
#             </div>
#             <img alt="" class="x38uc4-0 jOpoAq sc-1rp9nay-12 jZUqpg" height="72px" loading="lazy" src="https://megapx-assets.dcard.tw/images/7e661d17-85c4-425e-a274-20838d40eb18/640.jpeg" width="72px"/>
#            </article>
#           </div>
#          </div>
#          <div style="display:block">
#           <div class="rd4czy-0 eCXIkK">
#            <div class="kfwtwu-0 plPAm">
#             <svg height="100%" preserveaspectratio="none" viewbox="0 0 100 100" width="100%">
#              <defs>
#               <lineargradient gradientunits="userSpaceOnUse" id="lg" x1="-100%" x2="200%" y1="0" y2="0">
#                <stop class="jibxx0-0 gbKHmK" stop-color="#e5e5e5">
#                 <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0;0.8">
#                 </animate>
#                </stop>
#                <stop class="jibxx0-1 cCroaN" stop-color="#f5f5f5">
#                 <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.1;0.9">
#                 </animate>
#                </stop>
#                <stop class="jibxx0-0 gbKHmK" stop-color="#e5e5e5">
#                 <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.2;1">
#                 </animate>
#                </stop>
#               </lineargradient>
#              </defs>
#              <g fill="url(#lg)">
#               <rect height="16" width="30" x="0" y="0">
#               </rect>
#               <rect height="16" width="95" x="0" y="28">
#               </rect>
#               <rect height="16" width="50" x="0" y="56">
#               </rect>
#               <rect height="16" width="35" x="0" y="84">
#               </rect>
#              </g>
#             </svg>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#    <div class="r0dumd-0 eZbqml">
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TWLTW4M" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"query":{"hyper-version":"true"},"paginationOptions":{"forumAlias":"all"},"tabs":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","isHome":false}],"isForumRulePage":false}},"isLogin":false,"isMobile":true,"initialState":{"adConfigs":{"data":{"mobile_web_ad_type":{"MobileArticleBottom":"dfp","MobileLatestCommentsBottom":"dfp","MobilePopularCommentsBottom":"dfp","MobileLatestCommentsMiddle":"dfp","MobileArticleTop":"dfp","undefined":"off"},"mobile_web_campaigns":[],"hot_comments_hidden_post_authors":["dcardadangel","dcardecangel","dcardsvangel"],"post_engagement_idle":[],"post_engagement_interval":[],"web_adsenses":[{"id":"div-gpt-ad-1458631742813-0","name":"Desktop 右一","path":"/146730420/Desktop-Right-Top","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1466065536619-0","name":"Desktop 右二(原臉書上方)","path":"/146730420/Desktop-Beyond-FB","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1582095045953-0","name":"Desktop 右三摩天","path":"/146730420/Desktop-Right3","sizes":[{"width":300,"height":600}]},{"id":"div-gpt-ad-1582095257338-0","name":"Desktop 右四","path":"/146730420/Desktop-Right4","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1458631598292-0","name":"Desktop 右下摩天","path":"/146730420/Desktop-RightBottom-Bottom","sizes":[{"width":300,"height":600}]},{"id":"div-gpt-ad-1574770247619-0","name":"Desktop 全部回應 (10,30)","path":"/146730420/Desktop-Comments","sizes":[{"width":728,"height":90}]},{"id":"div-gpt-ad-1467085023952-0","name":"Desktop 單篇文章底部","path":"/146730420/Desktop-Article-Bottom","sizes":[{"width":728,"height":90}]},{"id":"div-gpt-ad-1487138000089-0","name":"Mobile Web 文章底部 (new)","path":"/146730420/Mobile-Web-Article-End","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1466051481599-0","name":"Mobile Web 人氣回應結束","path":"/146730420/Mweb-Popular-Comments","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1470381102159-0","name":"Mobile Web 全部回應 (每 30 則)","path":"/146730420/Mweb-Comments","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1458792275330-0","name":"Mobile Web 畫面底部","path":"/146730420/Mobile-Web-Screen-Bottom","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1471245470448-0","name":"Mobile Web 畫面頂部","path":"/146730420/Mobile-Web-Screen-Top","sizes":[{"width":300,"height":250}]}]},"error":null,"loading":false,"fetched":true},"app":{"data":{"headers":{"cf-ipcountry":"TW","referer":"https://www.google.com/","user-agent":"Mozilla/5.0 (Linux; Android 6.0.1; D6653) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.119 Mobile Safari/537.36","cf-device-type":"mobile","x-cloud-trace-context":"181dc6f4ed650d5b3c83c583ac2dd980/952755355555598111","true-client-ip":"36.227.187.236"},"isLogin":false,"isMobile":true,"userAgent":"Mozilla/5.0 (Linux; Android 6.0.1; D6653) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.119 Mobile Safari/537.36","ipCountry":"TW"},"error":null,"loading":false,"fetched":false},"auth":{"socialLogin":{}},"banner":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"channel":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{},"unread":0},"collection":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"comment":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"commentDraft":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPage ...
#   </script>
#   <script nomodule="" src="/_next/static/runtime/polyfills-2d4e7d85a7fae7062e19.js">
#   </script>
#   <script data-next-page="/forum" defer="" src="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/forum.js">
#   </script>
#   <script data-next-page="/_app" defer="" src="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/_app.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/88.dc66c05c3d54648ff23c.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/3c4859d19f00ad0f5d804de5d236492f40221cb1.7cca386140609e544ff4.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/121.010cb2e31f2e19d55b25.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/117.3b6ae08346082b6eeb6e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/122.36fac467ed3d00c822e2.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/80d87c3548640ac7623a7f3e4a7b23b6e2843474.a14f21e81ee4ca85b5a5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/104.ace3a73d22498f4b5957.js">
#   </script>
#   <script defer="" src="/_next/static/runtime/webpack-b0bf36eede7fd5ee5cfe.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework.b347b462804689eaf927.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/commons.a7927da712c2b615dfc7.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/594bfe24906a2ede671370e37681d9c23b5e51d0.dbf2953254398f42164a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/b25bcdb1e7ba05b12936d4c250bc53fdddb47360.7693a06c8d147e1bd3c6.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/b777109c05c1680f5141243e7355faf68105634d.a3ea63189e554c385099.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/fd9e4387cac53e3e01237a32ef8edb7c5ba4b868.d5dfc3ae04ba5cb3723e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/7359311a9d01ecba33641507c4f214be45e0106f.279ba96673904ae6e30c.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/b8d4382911fe490512a63d22ba2c08a046a34ef7.f163dec2906e5e0593a6.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/af326e5a2f24698a224ae59a0aa08ee75ac93aee.01f83f8c6bc436062955.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/6ed2ac0cfb28e2327638daeda163ae54e78a01ba.7100a99d0af72d20cd4a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/1f72ddc651f45282f9ccda39c7a63e5016539931.a0bb8772ba363a189a37.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2b8f6092e5f61fd3f7d20d35dae48f870ad9cfd4.2f1e8487244c4c0bef7c.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/9d907c18bbce1d8acda0eef070c9abff7334ab9f.754feaca83ad4aebe852.js">
#   </script>
#   <script defer="" src="/_next/static/runtime/main-a7f9ee31f9bcb2fc7fc0.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/7fa1ca47aca8ca1ec92bd86b0ce2561f39113bd6.cfe5dcd104c88ccb7266.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/b93030b0bbb2a681ce954d756d210dd3b22091cd.973fcdc6f3c8b3c0637e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/462f53e82956e978ffc7b9950012c598b58e8cd4.cff47e2afb4b09e017dd.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5ddffa3dcce25ac4eaa0d0b27025a332703dd129.0b621bd9b2b3e8b2d105.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/df0946cb4c0865cc26c76e30ee9a63d7ed2f4911.683e2507bd25f2b774ce.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/61b6311446725977a3716362d8e1c720eb271b31.9dd764b668b1cc4807a1.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/4079e89bf8ad6cb3c163afff3c8c5cabdbcb8914.41e27a9820e813260c8f.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/9f9d47bd318278b5f5032af054ffe9a1700e141c.f92a8f7fad2a2b7ea71e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/802b68d0d506bda42b98b2d01ae1fa07f5397ec9.89d48e6ab9ba067e9295.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/040f993490df8b4fbe225032a4f3be0be652010c.f2f3e1935c62763d9450.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/adf8d61cc41c535085045c051aea94432dc5f602.330f71984aec0e90a2b7.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/311537684536954336b90497a89d9e6866c0da94.06aab674237ef3df95d6.js">
#   </script>
#   <script defer="" src="/_next/static/qeULUZnaE40GZuX19ZeEu/_buildManifest.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### 知乎

# %%
# soup.prettify()可以美化排版
soup2 = BeautifulSoup(res_2,'lxml')
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js no-auth" dropeffect="none" lang="zh-CN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="default:None" http-equiv="X-ZA-Experiment"/>
#   <title>
#    发现 - 知乎
#   </title>
#   <meta content="app-id=432274380, app-argument=zhihu://explore" name="apple-itunes-app"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="format=html5;url=https://www.zhihu.com/explore" http-equiv="mobile-agent"/>
#   <meta content="1e11f9fbd76f425f9603b596e958ba00" id="znonce" name="znonce"/>
#   <link href="https://static.zhihu.com/static/revved/img/ios/touch-icon-152.87c020b9.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://static.zhihu.com/static/revved/img/ios/touch-icon-120.496c913b.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://static.zhihu.com/static/revved/img/ios/touch-icon-76.dcf79352.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://static.zhihu.com/static/revved/img/ios/touch-icon-60.9911cffb.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://static.zhihu.com/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://static.zhihu.com/static/search.xml" rel="search" title="知乎" type="application/opensearchdescription+xml"/>
#   <link href="https://static.zhihu.com/static/revved/-/css/m.7c4d48ad.css" rel="stylesheet"/>
#   <meta content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" name="google-site-verification"/>
#   <!--[if lt IE 9]>
# <script src="https://static.zhihu.com/static/components/respond/dest/respond.min.js"></script>
# <link href="https://static.zhihu.com/static/components/respond/cross-domain/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# <link href="/static/components/respond/cross-domain/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
# <script src="/static/components/respond/cross-domain/respond.proxy.js"></script>
# <![endif]-->
#   <script src="https://static.zhihu.com/static/revved/-/js/instant.35b468b8.js">
#   </script>
#  </head>
#  <body class="zhi page-explore">
#   <div class="zu-top" data-za-module="TopNavBar" role="navigation">
#    <div class="zg-wrap modal-shifting clearfix" id="zh-top-inner">
#     <a class="zu-top-link-logo" data-za-a="visit_home" data-za-c="view_home" data-za-l="top_navigation_zhihu_logo" href="/" id="zh-top-link-logo">
#      知乎
#     </a>
#     <ul class="topnav-noauth clearfix">
#      <li>
#       <span class="top-btn-inner-shdw">
#       </span>
#       <span class="top-btn-sep">
#       </span>
#      </li>
#      <li>
#       <a class="js-signup-noauth-mobile" href="javascript:;">
#        <span class="top-btn-inner-shdw left">
#        </span>
#        注册
#        <span class="top-btn-inner-shdw right">
#        </span>
#       </a>
#      </li>
#      <li>
#       <span class="top-btn-sep">
#       </span>
#      </li>
#      <li>
#       <a class="js-signin-noauth-mobile" href="javascript:;">
#        <span class="top-btn-inner-shdw left">
#        </span>
#        登录
#        <span class="top-btn-inner-shdw right">
#        </span>
#       </a>
#      </li>
#      <li>
#       <span class="top-btn-sep">
#       </span>
#      </li>
#      <li>
#       <a href="#" id="js-openInApp">
#        <span class="top-btn-inner-shdw left">
#        </span>
#        <i class="zg-icon zg-icon-cell">
#        </i>
#        打开 App
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div class="zu-global-notify" id="zh-global-message" style="display:none">
#    <div class="zg-wrap">
#     <div class="zu-global-nitify-inner">
#      <a class="zu-global-notify-close" href="javascript:;" name="close" title="关闭">
#       x
#      </a>
#      <span class="zu-global-notify-icon">
#      </span>
#      <span class="zu-global-notify-msg">
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="zg-wrap zu-main clearfix" role="main">
#    <div class="zu-main-content">
#     <div class="zu-main-content-inner">
#      <div id="zh-recommend">
#       <div class="page-title" id="zh-recommend-title">
#        <i class="zg-icon zg-icon-feedlist">
#        </i>
#        <span>
#         编辑推荐
#        </span>
#        <a class="zg-link-gray zg-right" data-za-a="visit_explore_recommendations" data-za-c="explore" data-za-l="editor_recommendations_more" href="/explore/recommendations">
#         <span>
#          更多推荐 »
#         </span>
#        </a>
#       </div>
#       <div id="zh-recommend-list">
#        <div class="top-recommend-feed feed-item">
#         <h2>
#          <a class="post-link" data-za-element-name="Title" href="https://zhuanlan.zhihu.com/p/109901092" target="_blank">
#           85点以上gal部分实体收录(4)
#          </a>
#         </h2>
#         <div class="avatar">
#          <a class="zm-item-link-avatar" data-hovercard="p$t$cheng-zi-pi-33-6" href="/people/cheng-zi-pi-33-6" target="_blank" title="橘子皮">
#           <img class="zm-item-img-avatar" src="https://pic2.zhimg.com/v2-488bb7ab6cecfad52cd43d164ee80484_m.jpg"/>
#          </a>
#         </div>
#         <div class="feed-main">
#          <div class="author-info">
#           <span class="author-link-line">
#            <a class="name author-link" data-hovercard="p$t$cheng-zi-pi-33-6" href="/people/cheng-zi-pi-33-6">
#             橘子皮
#            </a>
#           </span>
#           <span class="bio">
#            动漫，galgame，推理，文学
#           </span>
#          </div>
#          <div class="post-content">
#           <textarea class="content" hidden="">&lt;p&gt;自2月份中旬正式复工以来，抽空写了85点以上gal部分实体收录(4)。直至(4)为止我一共展示了40部85点及以上galgame的游戏本体，并简要发表了对每部作品的大致感受。哎，没想到这个坑已经填一半了。在(4.5)我将把我没玩过的或者我难以评价的作品做一个汇总，可能(4.5)会超过十部gal。剩下的85点作品评价由于凑不齐10部，也有因为客观因素没有购入的原因，会无限期停更。&lt;/p&gt;&lt;p&gt;届时应该会开两个新坑，一是galgame原声ost收录(个人向)，二是对于喜好的作品尝试写万字评价(这个坑其实有预兆，第一篇就是樱之诗)。&lt;/p&gt;&lt;p&gt;总感觉没必要把我想写的东西说的那么详细，毕竟我也不是那么勤快的人。&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic1.zhimg.com/v2-bd0534289b5a451dd5fbdc6505e1c478_b.jpg" data-rawwidth="2048" data-rawheight="1535" data-size="normal" class="origin_image zh-lightbox-thumb" width="2048" data-original="https://pic1.zhimg.com/v2-bd0534289b5a451dd5fbdc6505e1c478_r.jpg"/&gt;&lt;/figure&gt;&lt;p&gt;&lt;b&gt;31.phantom&lt;/b&gt;&lt;/p&gt;&lt;p&gt;会社:nitro+&lt;/p&gt;&lt;p&gt;脚本:虚渊玄&lt;/p&gt;&lt;p&gt;发售时间:2000/09/05&lt;/p&gt;&lt;p&gt;中央值:87&lt;/p&gt;&lt;p&gt;我毫不怀疑老虚借鉴了这个杀手不太冷里面杀手莱昂培养萝莉这段情节以及喋血双雄最后的教堂对决，模仿痕迹比较明显，phantom的故事或多或少都有港片的影子，组织、世仇、暗杀、包括深陷爱情与家族矛盾的黑道大小姐。从接纳组织，到最后背弃组织，为自己而战，这部当时据说领先业界十年的作品，其实一环一环看下来，故事的情节并不那么新鲜。老虚比较擅长杂和电影小说的情节来讲自己的故事，直白点说就是喜欢抄设定，集各家之所长，这就使得phantom即便现在看来依旧有非常耐人寻味的点。&lt;/p&gt;&lt;p&gt;与大多组织培养的杀手不同，phantom里的三位核心杀手并不是充当背景板的角色，他们的羁绊颇深，ein是玲二的师父，而玲二跟凯尔有一段孽缘。我不太理解凯尔恨玲二的理由，他们都曾彼此深爱过对方，动过真情，两年前住所的爆炸是一场误解，所以在玲二举枪杀死凯尔的那一刻后，玲二说&amp;#34;我们只是有一瞬间错过了对方而已&amp;#34;。这是我认为phantom震撼我的地方，曾经守护过爱过的人在最终因为立场的不同，成为了绊脚石，第一次是克劳迪娅，第二次是凯尔，而男主不得不亲手将他们送进坟墓。我对ein这个角色理解不是很深，更多时候她沉着冷静坚强，仿佛是为杀手而生，很难想象她去做其他什么事情的样子，综合来看是当之无愧的最强phantom。&lt;/p&gt;&lt;p&gt;phantom是老虚唯一一部上85点的作品，现在给老虚的标签大多是爱的战士，悲剧，虐心，治愈等等，然后各种神化老虚，一提到n+就是老虚，甚至还有一提到fate系就只有老虚;圆厨的神圣不可侵犯把我成功逼成了一个虚黑。实际上老虚也有写过不怎么黑，皆大欢喜的作品的，比如续杀戮之姜戈，我想如果不是有借鉴致敬&amp;#34;革命往事，西部往事，黄金三镖客&amp;#34;等一众西部片的成分在，续杀很可能是我老虚所有作品中最喜欢的，但这部作品中很多情节我就看了前一点点，就大致能猜到后面会发生什么，比如吹口琴的金发无名女，一下子就能想到复仇(西部往事);里面的甜水星直接引用了电影里的甜水镇。但不得不说，老虚还是漂亮地完成了这个故事，注入了自己的灵魂。&lt;/p&gt;&lt;p&gt;phantom的pc版一共有六个版本:&lt;/p&gt;&lt;p&gt;phantom of inferno初回版:2000/09/05(win85/98)&lt;/p&gt;&lt;p&gt;phantom of inferno廉价版:2002/07/12(win95/98/me/2000/xp)&lt;/p&gt;&lt;p&gt;phantom integration初回版:2004/09/17(win98/me/2000/xp)&lt;/p&gt;&lt;p&gt;phantom integration通常版:2004/11/19(win98/me/2000/xp)&lt;/p&gt;&lt;p&gt;phantom integration(nitro the best vol.1):2009/04/24(win2000/xp/Vista)&lt;/p&gt;&lt;p&gt;Phantom phantom of inferno:2013/8/30(此版本为13年重制版，增加语音，立绘cg全部重制，人设参考动画版)&lt;/p&gt;&lt;p&gt;个人买的是phantom integration初回版，个人认为重制版跟旧版各有优缺，但我比较偏好旧版，重制版虽然提升了画面，增加了语音，但是bgm非常催眠，不如旧版有紧张感。phantom integration初回版内部包含的特典有一张Special disk和一本比较薄的设定原画集。&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic3.zhimg.com/v2-90dcbf9b9a0ac955a1b10fc94a585996_b.jpg" data-rawwidth="1536" data-rawheight="2048" data-size="normal" class="origin_image zh-lightbox-thumb" width="1536" data-original="https://pic3.zhimg.com/v2-90dcbf9b9a0ac955a1b10fc94a585996_r.jpg"/&gt;&lt;/figure&gt;&lt;p class="ztext-empty-paragraph"&gt;&lt;br/&gt;&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic1.zhimg.com/v2-29e97abb1272609e317d4391afe3c8b0_b.jpg" data-rawwidth="1536" data-rawheight="2048" data-size="normal" class="origin_image zh-lightbox-thumb" width="1536" data-original="https://pic1.zhimg.com/v2-29e97abb1272609e317d4391afe3c8b0_r.jpg"/&gt;&lt;/figure&gt;&lt;p class="ztext-empty-paragraph"&gt;&lt;br/&gt;&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic1.zhimg.com/v2-c469d7dc57780bf2c39b451cb948b30c_b.jpg" data-rawwidth="1536" data-rawheight="2048" data-size="normal" class="origin_image zh-lightbox-thumb" width="1536" data-original="https://pic1.zhimg.com/v2-c469d7dc57780bf2c39b451cb948b30c_r.jpg"/&gt;&lt;/figure&gt;&lt;p class="ztext-empty-paragraph"&gt;&lt;br/&gt;&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic2.zhimg.com/v2-ab23d9473528ba2c9a79095bfa9c8d65_b.jpg" data-rawwidth="1536" data-rawheight="2048" data-size="normal" class="origin_image zh-lightbox-thumb" width="1536" data-original="https://pic2.zhimg.com/v2-ab23d9473528ba2c9a79095bfa9c8d65_r.jpg"/&gt;&lt;/figure&gt;&lt;p class="ztext-empty-paragraph"&gt;&lt;br/&gt ...
#           <div class="zh-summary summary clearfix">
#            自2月份中旬正式复工以来，抽空写了85点以上gal部分实体收录(4)。直至(4)为止我一共展示了40部85点及以上galgame的游戏本体，并简要发表了对每部作品的大致感受。哎，没想到这个坑已经填一半了。在(4.5)我将把我没玩过的或者我难以评价的作品做一个汇总，可…
#           </div>
#           <p class="hidden-default">
#            <a class="post-link entry-link" href="https://zhuanlan.zhihu.com/p/109901092" target="_blank">
#             昨天 21:45
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="recommend-feed feed-item">
#         <span class="zg-right zg-gray-normal feed-meta">
#          法兰克福学派与批判理论
#         </span>
#         <h2>
#          <a class="post-link" data-za-element-name="Title" href="https://zhuanlan.zhihu.com/p/110682313" target="_blank">
#           法的批判和批判的法：一种批判的法哲学观点
#          </a>
#         </h2>
#        </div>
#        <div class="recommend-feed feed-item">
#         <span class="zg-right zg-gray-normal feed-meta">
#          问答
#         </span>
#         <h2>
#          <a class="question_link" data-id="45572359" data-za-element-name="Title" href="/question/374822463/answer/1054008315" target="_blank">
#           看孩子上网课，她上课不守纪律，写作业敷衍了事，我变得特别暴躁且暴力，甚至动手打她，我该怎么办？
#          </a>
#         </h2>
#        </div>
#        <div class="recommend-feed feed-item">
#         <span class="zg-right zg-gray-normal feed-meta">
#          问答
#         </span>
#         <h2>
#          <a class="question_link" data-id="43213485" data-za-element-name="Title" href="/question/364207233/answer/1052529723" target="_blank">
#           如何评价《最终幻想7重制版》的试玩demo？
#          </a>
#         </h2>
#        </div>
#        <div class="recommend-feed feed-item">
#         <span class="zg-right zg-gray-normal feed-meta">
#          问答
#         </span>
#         <h2>
#          <a class="question_link" data-id="31847177" data-za-element-name="Title" href="/question/313067344/answer/1052668276" target="_blank">
#           如何评价游戏《南瓜先生大冒险》？
#          </a>
#         </h2>
#        </div>
#       </div>
#      </div>
#      <div class="explore-tab" id="js-explore-tab">
#       <a class="zg-anchor-hidden" name="daily-hot">
#       </a>
#       <a class="zg-anchor-hidden" name="monthly-hot">
#       </a>
#       <ul class="tab-navs clearfix">
#        <li class="tab-nav">
#         <a class="anchor" data-za-a="visit_explore_daily_trendings" data-za-c="explore" data-za-l="explore_daily_trendings" href="#daily-hot">
#          今日最热
#         </a>
#        </li>
#        <li class="tab-nav">
#         <a class="anchor" data-za-a="visit_explore_monthly_trendings" data-za-c="explore" data-za-l="explore_monthly_trendings" href="#monthly-hot">
#          本月最热
#         </a>
#        </li>
#       </ul>
#       <div class="tab-panel">
#        <div data-type="daily" data-zop-feedlist="">
#         <div class="explore-feed feed-item" data-offset="1">
#          <h2>
#           <a class="question_link" data-id="32625715" data-za-element-name="Title" href="/question/316572335/answer/1049250746" target="_blank">
#            宫崎骏为什么讨厌手冢治虫?
#           </a>
#          </h2>
#          <div class="zm-item-answer" data-aid="220839019" data-atoken="1049250746" data-collapsed="0" data-copyable="1" data-created="1583078940" data-deleted="0" data-helpful="True" data-isowner="0" data-zop="" itemscope="" itemtype="http://schema.org/Answer" tabindex="-1">
#           <link href="/question/316572335/answer/1049250746" itemprop="url"/>
#           <meta content="220839019" itemprop="answer-id"/>
#           <meta content="1049250746" itemprop="answer-url-token"/>
#           <a class="zg-anchor-hidden" name="answer-220839019">
#           </a>
#           <div class="answer-head">
#            <div class="zm-item-answer-author-info">
#             <span class="summary-wrapper">
#              <span class="author-link-line">
#               <a class="author-link" data-hovercard="p$t$aottoo" href="/people/aottoo" target="_blank">
#                TOTOLO
#               </a>
#              </span>
#              <span class="bio" title="纯朴吉卜力厨">
#               纯朴吉卜力厨
#              </span>
#             </span>
#            </div>
#            <div class="zm-item-vote-info" data-votecount="260">
#             <span class="voters text">
#              <a class="more text" href="#">
#               <span class="js-voteCount">
#                260
#               </span>
#               人赞同
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="zm-item-rich-text expandable js-collapse-body" data-action="/answer/content" data-author-name="TOTOLO" data-entry-url="/question/316572335/answer/1049250746" data-resourceid="32625715">
#            <textarea class="content" hidden="">&lt;p&gt;宫崎骏对手冢的”批评“确实是&lt;b&gt;非常难讲解&lt;/b&gt;的部分，&lt;b&gt;有合理的也有不合理的部分&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;合理的部分，主要集中在&lt;b&gt;动画技法&lt;/b&gt;上。&lt;/p&gt;&lt;p&gt;这部分确实是很难替手冢辩白，你如果仔细去看完《鲁邦三世：卡里奥斯特罗之城》和《火鸟2772：爱的宇宙空间》，然后再去看看手冢在此之间的言论，我觉得你就能理解了。&lt;/p&gt;&lt;p&gt;就是说，什么是一拍三，什么是一拍二，什么是有限动画，什么是全动画，动画的运动应该去追求什么，这个时间点的手冢给人的感受是非常&lt;b&gt;混乱&lt;/b&gt;的。这里非常容易被大家&lt;b&gt;误解&lt;/b&gt;的就是”&lt;i&gt;宫崎骏作为全动画的代表吊打了有限动画&lt;/i&gt;“，&lt;b&gt;这种观点是不对的&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;大家知道这里尴尬在什么地方吗？尴尬在，&lt;b&gt;《卡里奥斯特罗之城》就是代表着”全动画“与”有限动画“技法结合的，以拍三为主导的完整表达角色动作的动画作品&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;就是说，&lt;b&gt;你只要认真地看过《卡里奥斯特罗之城》，你不应该再对上面的那些概念有混淆了&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;然后尴尬的地方又来了，手冢的发言以及《火鸟2772：爱的宇宙空间》的成片时间，&lt;b&gt;全部在卡城之后&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;骂手冢骂的最狠的，除了宫崎骏就是他的师傅大冢康生，大家知道大冢康生的一个称呼是什么吗？&lt;/p&gt;&lt;p&gt;&lt;b&gt;缩减张数的天才&lt;/b&gt;&lt;/p&gt;&lt;p&gt;就是说，宫崎骏是拿拍三去表达全动画的监督，而大冢是灵活使用张数的先驱，这两个人看着手冢在那里大把大把乱用张数，不生气才怪。&lt;/p&gt;&lt;p&gt;还是那句话，&lt;b&gt;好好去看《卡里奥斯特罗之城》和《火鸟2772：爱的宇宙空间》&lt;/b&gt;，注意，&lt;b&gt;别看故事剧情看动作表达&lt;/b&gt;，然后琢磨一下手冢的发言：&lt;/p&gt;&lt;blockquote&gt;  我还没有看过《卡里奥斯特罗城》&lt;sup data-text="大冢康生：据手塚工作室的人说似乎其实在试映室里反复看了很多遍" data-url="" data-draft-node="inline" data-draft-type="reference" data-numero="1"&gt;[1]&lt;/sup&gt;。据说《卡里奥斯特罗城》是一拍三作画的，这次请大家帮忙的《火鸟》是全部用一拍二，全动画，请大家对这个要求多多关照&lt;/blockquote&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;上面的这部分实在是很难给手冢辩白，只能说，&lt;b&gt;人的精力是有限的&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;&lt;b&gt;但是，除此之外，宫崎骏对手冢治虫的批判，请各位一定要有自己的立场和判断&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;手冢治虫在日本动画发展的历史里绝对是极端重要的存在，这个和他个体的动画理念到什么地步甚至是没有什么关系的，这并不矛盾。&lt;/p&gt;&lt;p&gt;押井守的观点我认为是相对合理的，直接摘下来就可以：&lt;/p&gt;&lt;blockquote&gt;   对于手塚先生在动画领域所作的事情的意义——现在回过头来说这个哟——我认为有两个。其一就是所谓以日本式的意义缩减，用一拍三来制作动画这点。就算不是事先预计到的，这种做法也作为一种经济效果而得以成立。用更少的钱来制作，省力化得以实现。然后导致的结果，是和以&lt;b&gt;日后日本anime特有的控制能力&lt;/b&gt;来处理动画联系在一起的，换而言之就是&lt;b&gt;打开了通往真实系动画的道路&lt;/b&gt;。比如《科学忍者队ガッチャマン》之类也是，以这个意义来说基本就是以停止画面才得以成立的东西。&lt;b&gt;原本来说那种剧画式的画法，也不可能用一拍二让它圆润地动起来&lt;/b&gt;。从这方面的文脉来说的话，开拓了今日所称为真实系动画的道路。结果来说。这是其一。&lt;br&gt;   还有一点是将有剧情的戏剧性的展开带入到动画中来这件事。动画并不只是给人们看小动物的愉快动作这点。简而言之就是和东映划清界限。&lt;/blockquote&gt;&lt;p&gt;重点我都加粗了。&lt;/p&gt;&lt;p&gt;虽然手冢治虫本人并没有多少这样的意识，但是他的&lt;b&gt;实验性、冒险性&lt;/b&gt;，确实是&lt;b&gt;大大加速&lt;/b&gt;了这个过程的实现。&lt;/p&gt;&lt;p&gt;也许宫崎骏、大冢康生这样的创作者会说”才不是这样“，然后把押井守驳斥一顿，拿出另外一套说辞。但是我认为，对于宏观的日本动画的发展来讲，这样的说法是&lt;b&gt;蛮合适的&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;这一部分我不能给大家很准确判断的原因是，&lt;b&gt;很难讲宫崎骏的发展有没有受到手冢的间接影响&lt;/b&gt;。这一点我是无法给出一个靠谱结论的，而你如果从1977年开始一年一年地扫剧场动画，然后把宫崎骏的作品从《太阳王子》往后看的话，我觉得——&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic3.zhimg.com/v2-5637b08f631a881b9ff6e81efc51879e_b.jpg" data-caption="" data-size="normal" data-rawwidth="450" data-rawheight="239" class="origin_image zh-lightbox-thumb" width="450" data-original="https://pic3.zhimg.com/v2-5637b08f631a881b9ff6e81efc51879e_r.jpg"&gt;&lt;/figure&gt;&lt;p&gt;娜乌西卡这样向你跑来的时候，你会感到惊讶的。&lt;/p&gt;&lt;p&gt;就是说，从这一点出发，宫崎骏讲的：&lt;/p&gt;&lt;blockquote&gt;  整体来说，我希望将手冢治虫定位在「剧情漫画之创始者」和「&lt;b&gt;今日动画工作流程的制订者&lt;/b&gt;」上。为此，我在公开场合或文章中总是以「手冢治虫」直称——因为在这个定义上的他，是贤达先进而不是对手。就像我们写历史人物「伊藤博文」时不另加尊称一样——我想，这样的评价应该不会有偏颇吧。&lt;br&gt;  可惜在动画方面——只有在这个领域，我想我有权利和义务来做点声明——&lt;b&gt;手冢先生至今对动画界所发表的主张和意见，全都是错的&lt;/b&gt;。&lt;/blockquote&gt;&lt;p&gt;这样的批评就是勉强的、值得怀疑的。&lt;/p&gt;&lt;p&gt;就是说，严苛的讲，宫崎骏说手冢治虫在动画里的主张很混乱是没有问题的。&lt;b&gt;但是&lt;/b&gt;，要说手冢对动画本身的发展没有做出贡献，这是不对的。即使宫崎骏没有受到影响，那其他人呢？我想大家明白我的意思，这确实是一个&lt;b&gt;相当苛刻的批评&lt;/b&gt;。&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;至于宫崎骏对手冢治虫的”&lt;b&gt;人道主义&lt;/b&gt;“、”&lt;b&gt;虚无主义&lt;/b&gt;“的批判，那个我认为大家&lt;b&gt;务必有自己的思考&lt;/b&gt;，在这里不进行展开。&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;至于所谓的”&lt;b&gt;廉价制作费&lt;/b&gt;“之类的事情，我用宫崎骏原话进行解释：&lt;/p&gt;&lt;blockquote&gt;  经费受限固然是一大不幸，但我认为它只不过是日本在经济成长的过程中&lt;b&gt;必然产生的一个现象罢了&lt;/b&gt;，换句话说，&lt;b&gt;动画早晚要走上这个命运，只是手冢先生恰巧扣下了扳机&lt;/b&gt;。&lt;br&gt;  倘若当时不是他那么做，日本动画或许还能苟延残喘个二、三年，那么我只要稍稍勒紧腰带，就能用以前的作法再拍一部长篇动画了。&lt;/blockquote&gt;&lt;p&gt;宫崎骏都不认为手冢背锅，没啥好说的。&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;&lt;br ...
#            <div class="zh-summary summary clearfix">
#             <img class="origin_image inline-img zh-lightbox-thumb" data-caption="" data-original="https://pic3.zhimg.com/v2-5637b08f631a881b9ff6e81efc51879e_r.jpg" data-original-src="v2-5637b08f631a881b9ff6e81efc51879e" data-private-watermark-src="" data-rawheight="239" data-rawwidth="450" data-size="normal" data-watermark="watermark" data-watermark-src="" src="https://pic3.zhimg.com/v2-5637b08f631a881b9ff6e81efc51879e_200x112.jpg"/>
#             宫崎骏对手冢的”批评“确实是
#             <b>
#              非常难讲解
#             </b>
#             的部分，
#             <b>
#              有合理的也有不合理的部分
#             </b>
#             。 合理的部分，主要集中在
#             <b>
#              动画技法
#             </b>
#             上。这部分确实是很难替手冢辩白，你如果仔细去看完《鲁邦三世：卡里奥斯特罗之城》和《火鸟2772：爱的宇宙空间》，然后再去看看手冢在此之间的…
#             <a class="toggle-expand" href="/question/316572335/answer/1049250746">
#              显示全部
#             </a>
#            </div>
#            <p class="visible-expanded">
#             <a class="answer-date-link meta-item" href="/question/316572335/answer/1049250746" itemprop="url" target="_blank">
#              发布于 2020-03-02
#             </a>
#            </p>
#           </div>
#           <div class="zm-item-meta answer-actions clearfix js-contentActions">
#            <div class="zm-meta-panel">
#             <a class="meta-item votenum-mobile zm-item-vote-count js-openVoteDialog" href="#">
#              <span data-bind-votecount="">
#               260
#              </span>
#              <i class="arrow zg-icon">
#              </i>
#             </a>
#             <div class="zm-votebar">
#              <button class="up">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="count">
#                260
#               </span>
#               <span class="label sr-only">
#                赞同
#               </span>
#              </button>
#              <button class="down">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="label sr-only">
#                反对
#               </span>
#              </button>
#             </div>
#             <a class="follow-link zg-follow meta-item" data-follow="q:link" href="javascript:;" id="sfb-32625715">
#              <i class="z-icon-follow">
#              </i>
#              关注问题
#             </a>
#             <a class="meta-item toggle-comment js-toggleCommentBox" href="#" name="addcomment">
#              <i class="z-icon-comment">
#              </i>
#              13 条评论
#             </a>
#             <a class="meta-item zu-autohide js-thank" data-thanked="false" href="#">
#              <i class="z-icon-thank">
#              </i>
#              感谢
#             </a>
#             <span class="phone-actions">
#              <a class="menubutton more-actions meta-item zu-autohide" href="#">
#               <i class="zg-icon zg-icon-ellipsis-mobi">
#               </i>
#               <span class="hide-text">
#                更多
#               </span>
#              </a>
#              <div class="menu goog-menu goog-menu-vertical zh-answer-more-actions" style="display:none">
#               <div class="goog-menuitem js-share">
#                分享
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-collect">
#                收藏
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-noHelp">
#                没有帮助
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-report">
#                举报
#               </div>
#              </div>
#             </span>
#             <meta content="1" name="copyrightStatus"/>
#             <meta content="" name="disableCopyAvatar"/>
#             <span class="zg-bull">
#              •
#             </span>
#             <a class="meta-item copyright" href="/terms#sec-licence-1" target="_blank">
#              作者保留权利
#             </a>
#             <button class="meta-item item-collapse js-collapse">
#              <i class="z-icon-fold">
#              </i>
#              收起
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="explore-feed feed-item" data-offset="2">
#          <h2>
#           <a class="question_link" data-id="45792594" data-za-element-name="Title" href="/question/375814719/answer/1049235219" target="_blank">
#            如何看待杨超越代言乐事？
#           </a>
#          </h2>
#          <div class="zm-item-answer" data-aid="220836203" data-atoken="1049235219" data-collapsed="0" data-copyable="1" data-created="1583078477" data-deleted="0" data-helpful="True" data-isowner="0" data-zop="" itemscope="" itemtype="http://schema.org/Answer" tabindex="-1">
#           <link href="/question/375814719/answer/1049235219" itemprop="url"/>
#           <meta content="220836203" itemprop="answer-id"/>
#           <meta content="1049235219" itemprop="answer-url-token"/>
#           <a class="zg-anchor-hidden" name="answer-220836203">
#           </a>
#           <div class="answer-head">
#            <div class="zm-item-answer-author-info">
#             <span class="summary-wrapper">
#              <span class="author-link-line">
#               <a class="author-link" data-hovercard="p$t$jiang-zhi-ze-96" href="/people/jiang-zhi-ze-96" target="_blank">
#                咖啡色的多瑙河
#               </a>
#              </span>
#              <span class="bio" title="开阔的眼界，有趣的灵魂，豁达的态度">
#               开阔的眼界，有趣的灵魂，豁达的态度
#              </span>
#             </span>
#            </div>
#            <div class="zm-item-vote-info" data-votecount="90">
#             <span class="voters text">
#              <a class="more text" href="#">
#               <span class="js-voteCount">
#                90
#               </span>
#               人赞同
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="zm-item-rich-text expandable js-collapse-body" data-action="/answer/content" data-author-name="咖啡色的多瑙河" data-entry-url="/question/375814719/answer/1049235219" data-resourceid="45792594">
#            <textarea class="content" hidden="">&lt;p&gt;说句题外的话，很多人认为这个问题上热榜涉嫌营销炒作，或者说是粉丝自嗨。&lt;/p&gt;&lt;p&gt;这个粉丝自嗨的说法我们可以认，但之所以上热榜，那是因为杨超越粉丝的人数体量和加权体量（计算综合级别盐值等，可以折算成发言声量，言论传播能力），在知乎单一群体中真的是数一数二的了。因此杨超越的一些大的话题和动向，羊村在相关问题下稍微聚集起来，就足以使其成为一个在热榜上呆个一天半天的问题。如果有些争议的话还会是高位热搜。这个问题下面我看很多熟悉的名字根本也还没出现呢，知乎羊村的风格其实已经在某几个关键节点后开始偏佛系和克制了。&lt;/p&gt;&lt;p&gt;你说为什么会这样，是不是饭圈大规模入侵破乎了？大可不必，有人的地方就有江湖，粉黑大战，粉丝自嗨，路人吃瓜，各种情绪碰撞原本都是网络的常态，不会因为知乎er人均985就不同了，只是知乎相对更加理性，更加克制，讲究以理服人。杨超越的粉丝很多都是原住民也不是外来的，只是这两年碰巧被这个小姑娘吸粉了而已，并没有鸠占鹊巢，希望知乎和知乎er能拥有足够的包容性和“App自信”吧 &lt;/p&gt;&lt;p&gt;至于说营销和水军的，这个咱确实不能认，咱们这种为爱发电的，认了这个多亏啊 ……想想杨超越都被说了两年团队营销强大，实际上背后却是个p事儿不干躺着拿钱的皮包公司，真的是一口老血……&lt;/p&gt;&lt;p&gt;———————————————————————&lt;/p&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;p&gt;杨超越与乐事品牌的这次合作，说明杨超越在行业头部品牌商家心目中初步具备了成为“国民品牌代言人”的资质，而这种资质来源于艺人足够的国民度和美誉度，缺一不可。&lt;/p&gt;&lt;p&gt;乐事薯片，在我看来就是零食中的“选项c”，不知道想买点啥零食？来袋乐事吧！好吃不贵，消闲必备，就是这么个地位，在零食中是有它特定的统治力在的。&lt;/p&gt;&lt;p&gt;杨超越是什么形象呢？除了在小部分网民那儿吧，总体来说她在广大人民群众心目中形象是向上的，是健康的，也是可爱而受欢迎的。你看她的称呼就知道了：超越妹妹，叫某某姐姐的不好说，但一般叫妹妹的形象都差不了吧？她未必要最有才最漂亮，但妹妹就是妹妹，谁会说妹妹的不是呢，对不？&lt;/p&gt;&lt;p&gt;所以在我看来这次合作是有其必然性的，杨超越的正面形象和乐事的品牌形象正好能相得益彰，形成了合作关系中最为良性的双赢局面。&lt;/p&gt;&lt;p&gt;哦对了，谁来科普一下乐事哪个味道最好吃？我土鳖只吃过原味的……&lt;/p&gt;</textarea>
#            <div class="zh-summary summary clearfix">
#             说句题外的话，很多人认为这个问题上热榜涉嫌营销炒作，或者说是粉丝自嗨。这个粉丝自嗨的说法我们可以认，但之所以上热榜，那是因为杨超越粉丝的人数体量和加权体量（计算综合级别盐值等，可以折算成发言声量，言论传播能力），在知乎单一群体中真的是数一…
#             <a class="toggle-expand" href="/question/375814719/answer/1049235219">
#              显示全部
#             </a>
#            </div>
#            <p class="visible-expanded">
#             <a class="answer-date-link meta-item" data-tooltip="s$t$发布于 2020-03-02" href="/question/375814719/answer/1049235219" itemprop="url" target="_blank">
#              编辑于 2020-03-02
#             </a>
#            </p>
#           </div>
#           <div class="zm-item-meta answer-actions clearfix js-contentActions">
#            <div class="zm-meta-panel">
#             <a class="meta-item votenum-mobile zm-item-vote-count js-openVoteDialog" href="#">
#              <span data-bind-votecount="">
#               90
#              </span>
#              <i class="arrow zg-icon">
#              </i>
#             </a>
#             <div class="zm-votebar">
#              <button class="up">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="count">
#                90
#               </span>
#               <span class="label sr-only">
#                赞同
#               </span>
#              </button>
#              <button class="down">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="label sr-only">
#                反对
#               </span>
#              </button>
#             </div>
#             <a class="follow-link zg-follow meta-item" data-follow="q:link" href="javascript:;" id="sfb-45792594">
#              <i class="z-icon-follow">
#              </i>
#              关注问题
#             </a>
#             <a class="meta-item toggle-comment js-toggleCommentBox" href="#" name="addcomment">
#              <i class="z-icon-comment">
#              </i>
#              11 条评论
#             </a>
#             <a class="meta-item zu-autohide js-thank" data-thanked="false" href="#">
#              <i class="z-icon-thank">
#              </i>
#              感谢
#             </a>
#             <span class="phone-actions">
#              <a class="menubutton more-actions meta-item zu-autohide" href="#">
#               <i class="zg-icon zg-icon-ellipsis-mobi">
#               </i>
#               <span class="hide-text">
#                更多
#               </span>
#              </a>
#              <div class="menu goog-menu goog-menu-vertical zh-answer-more-actions" style="display:none">
#               <div class="goog-menuitem js-share">
#                分享
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-collect">
#                收藏
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-noHelp">
#                没有帮助
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-report">
#                举报
#               </div>
#              </div>
#             </span>
#             <meta content="1" name="copyrightStatus"/>
#             <meta content="" name="disableCopyAvatar"/>
#             <span class="zg-bull">
#              •
#             </span>
#             <a class="meta-item copyright" href="/terms#sec-licence-1" target="_blank">
#              作者保留权利
#             </a>
#             <button class="meta-item item-collapse js-collapse">
#              <i class="z-icon-fold">
#              </i>
#              收起
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="explore-feed feed-item" data-offset="3">
#          <h2>
#           <a class="question_link" data-id="45792594" data-za-element-name="Title" href="/question/375814719/answer/1049199482" target="_blank">
#            如何看待杨超越代言乐事？
#           </a>
#          </h2>
#          <div class="zm-item-answer" data-aid="220829813" data-atoken="1049199482" data-collapsed="0" data-copyable="1" data-created="1583077544" data-deleted="0" data-helpful="True" data-isowner="0" data-zop="" itemscope="" itemtype="http://schema.org/Answer" tabindex="-1">
#           <link href="/question/375814719/answer/1049199482" itemprop="url"/>
#           <meta content="220829813" itemprop="answer-id"/>
#           <meta content="1049199482" itemprop="answer-url-token"/>
#           <a class="zg-anchor-hidden" name="answer-220829813">
#           </a>
#           <div class="answer-head">
#            <div class="zm-item-answer-author-info">
#             <span class="summary-wrapper">
#              <span class="author-link-line">
#               <span class="name">
#                知乎用户
#               </span>
#              </span>
#             </span>
#            </div>
#            <div class="zm-item-vote-info" data-votecount="62">
#             <span class="voters text">
#              <a class="more text" href="#">
#               <span class="js-voteCount">
#                62
#               </span>
#               人赞同
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="zm-item-rich-text expandable js-collapse-body" data-action="/answer/content" data-author-name="神器生物独角兽" data-entry-url="/question/375814719/answer/1049199482" data-resourceid="45792594">
#            <textarea class="content" hidden="">&lt;p&gt;在落笔时我回想了一下，平时买薯片一般买什么牌子的，印象中好像只买“乐事”，没买过其他牌子，这就是“国民度”吧。因此我对于乐事请杨超越担任全线代言人一点也不奇怪。毕竟国民品牌的代言人也必须是有“国民度”的，杨超越恰恰是合适的人选。要知道，在此之前官宣的几位代言人，如李现，杨紫等，同样具备这样的要素。&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic1.zhimg.com/v2-100b5fdeaa064bd641db49b0bc02e7b4_b.jpg" data-rawwidth="776" data-rawheight="198" data-size="normal" data-default-watermark-src="https://pic1.zhimg.com/v2-d5a5e6e53db6838952a4707ce481517c_b.jpg" class="origin_image zh-lightbox-thumb" width="776" data-original="https://pic1.zhimg.com/v2-100b5fdeaa064bd641db49b0bc02e7b4_r.jpg"&gt;&lt;/figure&gt;&lt;p&gt;这里不妨岔开说一下杨超越的“影响力”，就拿最近播出的《了不起的长城》，有杨超越出场的第五期和第一期，都是周六档卫视节目的收视冠军，可以压制同期的快乐大本营，非诚勿扰等老牌综艺，从一到五期收视率更是一个性感的“深V”，这就叫“影响力”吧。&lt;/p&gt;&lt;p&gt;纵观杨超越迄今为止代言过的产品，从翻译笔到治咳嗽的，从运动装备到手游，从酸奶到薯片，从化妆品到卫生巾，五花八门，从初期代言产品略冷门以外，其余的无一不是在消费市场上耳熟能详的大品牌。&lt;/p&gt;&lt;p&gt;所谓代言人，就是产品价值的体现，是品牌战略者们聘请或塑造的，能让人们通过对其知名度、职业、形象、个性、品行的联想，产生对某种品牌美好印象的人。代言人发挥作用的机理是情感移植。可以引领品牌形象、体现品牌个性、造成品牌识别、增加品牌权益。百事集团旗下的乐事请杨超越坐代言人恐怕也是基于其贴合产品受众群，能凸现品牌形象的考虑吧。&lt;/p&gt;&lt;p&gt;所为一名乐事薯片爱好者来说，能买到自己喜欢的明星代言的产品，真的是一举两得，双赢。为乐事点赞。&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic3.zhimg.com/v2-2a440817481a034eb1d85b344d81d5da_b.jpg" data-rawwidth="832" data-rawheight="1258" data-size="normal" data-default-watermark-src="https://pic3.zhimg.com/v2-d1cc2572ae8c0956ef2255d4cdb6683e_b.jpg" class="origin_image zh-lightbox-thumb" width="832" data-original="https://pic3.zhimg.com/v2-2a440817481a034eb1d85b344d81d5da_r.jpg"&gt;&lt;figcaption&gt;注：宣传图上的“春季限定”特指限定款的薯片&lt;/figcaption&gt;&lt;/figure&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic4.zhimg.com/v2-9a1b6a265ddbf68f754bfbcba3f8297f_b.jpg" data-rawwidth="1080" data-rawheight="1934" data-size="normal" data-default-watermark-src="https://pic2.zhimg.com/v2-74fd8beee888932b07c6ed5e9da5faf1_b.jpg" class="origin_image zh-lightbox-thumb" width="1080" data-original="https://pic4.zhimg.com/v2-9a1b6a265ddbf68f754bfbcba3f8297f_r.jpg"&gt;&lt;/figure&gt;&lt;p&gt;今天同时网上某平台还在直播售卖，去乐事的直播间瞅了一下，还在欢乐地直播呢，点赞已经到一千三百九十万了，想起了去年卖狗皮的那场直播。&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic4.zhimg.com/v2-16f509d5331fdfe40eb6de8f430d0b33_b.jpg" data-rawwidth="1080" data-rawheight="2160" data-size="normal" data-default-watermark-src="https://pic3.zhimg.com/v2-1767e45d14a9ac2bda8fb8ed87ea068a_b.jpg" class="origin_image zh-lightbox-thumb" width="1080" data-original="https://pic4.zhimg.com/v2-16f509d5331fdfe40eb6de8f430d0b33_r.jpg"&gt;&lt;figcaption&gt;3月1日23：41，我的截图&lt;/figcaption&gt;&lt;/figure&gt;&lt;p&gt;&lt;br&gt;&lt;/p&gt;&lt;figure data-size="normal"&gt;&lt;img src="https://pic1.zhimg.com/v2-399cf90d51fca941b4c5e8c475c71654_b.jpg" data-rawwidth="1080" data-rawheight="1920" data-size="normal" data-default-watermark-src="https://pic3.zhimg.com/v2-40ef3492397479749a567e06cd7e3f0e_b.jpg" class="origin_image zh-lightbox-thumb" width="1080" data-original="https://pic1.zhimg.com/v2-399cf90d51fca941b4c5e8c475c71654_r.jpg"&gt;&lt;figcaption&gt;网上找的&lt;/figcaption&gt;&lt;/figure&gt;&lt;p&gt;&lt;/p&gt;</textarea>
#            <div class="zh-summary summary clearfix">
#             <img class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic1.zhimg.com/v2-100b5fdeaa064bd641db49b0bc02e7b4_r.jpg" data-original-src="v2-100b5fdeaa064bd641db49b0bc02e7b4" data-private-watermark-src="v2-d5a5e6e53db6838952a4707ce481517c" data-rawheight="198" data-rawwidth="776" data-size="normal" data-watermark="original" data-watermark-src="v2-cb80abe621abce1ff89c640f14dfcb33" src="https://pic1.zhimg.com/v2-100b5fdeaa064bd641db49b0bc02e7b4_200x112.jpg"/>
#             在落笔时我回想了一下，平时买薯片一般买什么牌子的，印象中好像只买“乐事”，没买过其他牌子，这就是“国民度”吧。因此我对于乐事请杨超越担任全线代言人一点也不奇怪。毕竟国民品牌的代言人也必须是有“国民度”的，杨超越恰恰是合适的人选。要知道，在…
#             <a class="toggle-expand" href="/question/375814719/answer/1049199482">
#              显示全部
#             </a>
#            </div>
#            <p class="visible-expanded">
#             <a class="answer-date-link meta-item" href="/question/375814719/answer/1049199482" itemprop="url" target="_blank">
#              发布于 2020-03-01
#             </a>
#            </p>
#           </div>
#           <div class="zm-item-meta answer-actions clearfix js-contentActions">
#            <div class="zm-meta-panel">
#             <a class="meta-item votenum-mobile zm-item-vote-count js-openVoteDialog" href="#">
#              <span data-bind-votecount="">
#               62
#              </span>
#              <i class="arrow zg-icon">
#              </i>
#             </a>
#             <div class="zm-votebar">
#              <button class="up">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="count">
#                62
#               </span>
#               <span class="label sr-only">
#                赞同
#               </span>
#              </button>
#              <button class="down">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="label sr-only">
#                反对
#               </span>
#              </button>
#             </div>
#             <a class="follow-link zg-follow meta-item" data-follow="q:link" href="javascript:;" id="sfb-45792594">
#              <i class="z-icon-follow">
#              </i>
#              关注问题
#             </a>
#             <a class="meta-item toggle-comment js-toggleCommentBox" href="#" name="addcomment">
#              <i class="z-icon-comment">
#              </i>
#              2 条评论
#             </a>
#             <a class="meta-item zu-autohide js-thank" data-thanked="false" href="#">
#              <i class="z-icon-thank">
#              </i>
#              感谢
#             </a>
#             <span class="phone-actions">
#              <a class="menubutton more-actions meta-item zu-autohide" href="#">
#               <i class="zg-icon zg-icon-ellipsis-mobi">
#               </i>
#               <span class="hide-text">
#                更多
#               </span>
#              </a>
#              <div class="menu goog-menu goog-menu-vertical zh-answer-more-actions" style="display:none">
#               <div class="goog-menuitem js-share">
#                分享
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-collect">
#                收藏
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-noHelp">
#                没有帮助
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-report">
#                举报
#               </div>
#              </div>
#             </span>
#             <meta content="1" name="copyrightStatus"/>
#             <meta content="" name="disableCopyAvatar"/>
#             <span class="zg-bull">
#              •
#             </span>
#             <a class="meta-item copyright" href="/terms#sec-licence-1" target="_blank">
#              作者保留权利
#             </a>
#             <button class="meta-item item-collapse js-collapse">
#              <i class="z-icon-fold">
#              </i>
#              收起
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="explore-feed feed-item" data-offset="4">
#          <h2>
#           <a class="question_link" data-id="38173710" data-za-element-name="Title" href="/question/341535719/answer/1049203453" target="_blank">
#            为什么不喜欢墨香铜臭？
#           </a>
#          </h2>
#          <div class="zm-item-answer" data-aid="220830537" data-atoken="1049203453" data-collapsed="0" data-copyable="1" data-created="1583077643" data-deleted="0" data-helpful="True" data-isowner="0" data-zop="" itemscope="" itemtype="http://schema.org/Answer" tabindex="-1">
#           <link href="/question/341535719/answer/1049203453" itemprop="url"/>
#           <meta content="220830537" itemprop="answer-id"/>
#           <meta content="1049203453" itemprop="answer-url-token"/>
#           <a class="zg-anchor-hidden" name="answer-220830537">
#           </a>
#           <div class="answer-head">
#            <div class="zm-item-answer-author-info">
#             <span class="summary-wrapper">
#              <span class="author-link-line">
#               <a class="author-link" data-hovercard="p$t$golden-stars" href="/people/golden-stars" target="_blank">
#                golden stars
#               </a>
#              </span>
#              <span class="bio" title="群众从未渴求过真理，他们对不合口味的证据视而不见。">
#               群众从未渴求过真理，他们对不合口味的证…
#              </span>
#             </span>
#            </div>
#            <div class="zm-item-vote-info" data-votecount="45">
#             <span class="voters text">
#              <a class="more text" href="#">
#               <span class="js-voteCount">
#                45
#               </span>
#               人赞同
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="zm-item-rich-text expandable js-collapse-body" data-action="/answer/content" data-author-name="golden stars" data-entry-url="/question/341535719/answer/1049203453" data-resourceid="38173710">
#            <textarea class="content" hidden="">&lt;p&gt;曾经有一段时间也对她没有好感。&lt;/p&gt;&lt;p&gt;讲一下我自己的经历吧，以前是混ACG圈的，原耽看的很少，两年多前住院的时候太无聊了爬晋江的榜发现魔道是第一就打开看了，从此一发不可收拾，不光是原著，同人衍生质量也很高，所以当时每天都吃粮吃的很开心，这个时候我是不关注作者的，所以也不了解那些乱七八糟的，当时晋江榜上排名靠前的文都看了，但是只有魔道后劲最大，让我久久走不出来。&lt;/p&gt;&lt;p&gt;后来就是和西子绪的事吧闹的挺大的，我前圈的朋友也给我科普墨香的黑料，当时半信半疑的，我确实不了解墨香本人，对那些所谓的黑料也没办法反驳。我个人对所有原耽作者都不真情实感也没有太在意，只是下意识避开了关于作者本人的东西，只想做个单纯看文的，所以并不知道那场风波给墨香带来了怎样的打击。&lt;/p&gt;&lt;p&gt;直到所谓的人肉事件发生我才真正去了解这些粉粉黑黑的，当时我在魔道超话发了帖子安慰那些很不安的粉丝，我不喜欢连坐这一套，就算人肉事件是真的也不应该让所有喜欢这本书的人都被骂，这太荒谬了，结果被黑子追着各种骂甚至在黑超话艾特我轮着骂，这个阵仗真是惊到我了，我的逆反心理一下子就上来了，去看了很多澄清，包括以前我不了解的事情，那些黑料都得到了解释，其实认真看了粉丝的澄清就会知道黑子所谓的盘和料都是毫无逻辑的，我坚信自己的判断，墨香铜臭不是什么大恶人，她的粉丝也没有那么可怕，被妖魔化地太厉害了，也许是有些地方做的不妥但是完全没有理由被辱骂到这个地步。&lt;/p&gt;&lt;p&gt;有些时候换个角度去看一些事情才会发现真相，如果一辈子不睁开眼去看去听只会被蒙蔽做了别人的枪，我不想做这种人。&lt;/p&gt;&lt;p&gt;讨厌一个人的权利人人都有，但是请不要造谣，不要让冲动和个人感情支配你的判断力。&lt;/p&gt;</textarea>
#            <div class="zh-summary summary clearfix">
#             曾经有一段时间也对她没有好感。讲一下我自己的经历吧，以前是混ACG圈的，原耽看的很少，两年多前住院的时候太无聊了爬晋江的榜发现魔道是第一就打开看了，从此一发不可收拾，不光是原著，同人衍生质量也很高，所以当时每天都吃粮吃的很开心，这个时候我是…
#             <a class="toggle-expand" href="/question/341535719/answer/1049203453">
#              显示全部
#             </a>
#            </div>
#            <p class="visible-expanded">
#             <a class="answer-date-link meta-item" data-tooltip="s$t$发布于 2020-03-01" href="/question/341535719/answer/1049203453" itemprop="url" target="_blank">
#              编辑于 2020-03-02
#             </a>
#            </p>
#           </div>
#           <div class="zm-item-meta answer-actions clearfix js-contentActions">
#            <div class="zm-meta-panel">
#             <a class="meta-item votenum-mobile zm-item-vote-count js-openVoteDialog" href="#">
#              <span data-bind-votecount="">
#               45
#              </span>
#              <i class="arrow zg-icon">
#              </i>
#             </a>
#             <div class="zm-votebar">
#              <button class="up">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="count">
#                45
#               </span>
#               <span class="label sr-only">
#                赞同
#               </span>
#              </button>
#              <button class="down">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="label sr-only">
#                反对
#               </span>
#              </button>
#             </div>
#             <a class="follow-link zg-follow meta-item" data-follow="q:link" href="javascript:;" id="sfb-38173710">
#              <i class="z-icon-follow">
#              </i>
#              关注问题
#             </a>
#             <a class="meta-item toggle-comment js-toggleCommentBox" href="#" name="addcomment">
#              <i class="z-icon-comment">
#              </i>
#              4 条评论
#             </a>
#             <a class="meta-item zu-autohide js-thank" data-thanked="false" href="#">
#              <i class="z-icon-thank">
#              </i>
#              感谢
#             </a>
#             <span class="phone-actions">
#              <a class="menubutton more-actions meta-item zu-autohide" href="#">
#               <i class="zg-icon zg-icon-ellipsis-mobi">
#               </i>
#               <span class="hide-text">
#                更多
#               </span>
#              </a>
#              <div class="menu goog-menu goog-menu-vertical zh-answer-more-actions" style="display:none">
#               <div class="goog-menuitem js-share">
#                分享
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-collect">
#                收藏
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-noHelp">
#                没有帮助
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-report">
#                举报
#               </div>
#              </div>
#             </span>
#             <meta content="1" name="copyrightStatus"/>
#             <meta content="" name="disableCopyAvatar"/>
#             <span class="zg-bull">
#              •
#             </span>
#             <a class="meta-item copyright" href="/terms#sec-licence-1" target="_blank">
#              作者保留权利
#             </a>
#             <button class="meta-item item-collapse js-collapse">
#              <i class="z-icon-fold">
#              </i>
#              收起
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="explore-feed feed-item" data-offset="5">
#          <h2>
#           <a class="question_link" data-id="32625715" data-za-element-name="Title" href="/question/316572335/answer/1049455167" target="_blank">
#            宫崎骏为什么讨厌手冢治虫?
#           </a>
#          </h2>
#          <div class="zm-item-answer" data-aid="220876247" data-atoken="1049455167" data-collapsed="0" data-copyable="1" data-created="1583087453" data-deleted="0" data-helpful="True" data-isowner="0" data-zop="" itemscope="" itemtype="http://schema.org/Answer" tabindex="-1">
#           <link href="/question/316572335/answer/1049455167" itemprop="url"/>
#           <meta content="220876247" itemprop="answer-id"/>
#           <meta content="1049455167" itemprop="answer-url-token"/>
#           <a class="zg-anchor-hidden" name="answer-220876247">
#           </a>
#           <div class="answer-head">
#            <div class="zm-item-answer-author-info">
#             <span class="summary-wrapper">
#              <span class="author-link-line">
#               <span class="name">
#                知乎用户
#               </span>
#              </span>
#              <span class="bio" title="— 你为什么总是穿着黑衣服？ — 我在给我的生活挂孝啊。">
#               — 你为什么总是穿着黑衣服？
# — 我在给…
#              </span>
#             </span>
#            </div>
#            <div class="zm-item-vote-info" data-votecount="406">
#             <span class="answer-tag">
#              <span class="text">
#               收录于
#              </span>
#              <span class="text">
#               编辑推荐
#              </span>
#             </span>
#             <span class="voters text">
#              <a class="more text" href="#">
#               <span class="js-voteCount">
#                406
#               </span>
#               人赞同
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="zm-item-rich-text expandable js-collapse-body" data-action="/answer/content" data-author-name="Xie3 Project" data-entry-url="/question/316572335/answer/1049455167" data-resourceid="32625715">
# ...
#            <textarea class="content" hidden="">&lt;p&gt;看了一下视频来源，这不是著名的已经疯魔了的肖战黑吗？你朋友给你发这个视频的时候应该没告诉过你这个人的事迹吧，最著名的就是开直播在线诅咒肖战，是诅咒哦，涉及生命的那种，造谣要黑肖战，P图也要黑肖战，就是一个没有底线的，一会儿威胁肖战告她她就自杀，一会儿让人随便告她，这种人一般只有两种情况，要么领工资的职黑，要么精神有问题。而且此人是精日人士，微博公开diss自己祖国，做人还是要有点底线的。坦白讲你传的是这个人的视频，还一口一个战战，真的让我咯噔了一下，希望是我想多了吧。如果真的是我想多了，上面的这段话就当是我给新粉普及一下了。&lt;/p&gt;&lt;p&gt;肖战在明显会被记录下来的情况下翻白眼，还是如此大幅度的白眼，本身就有开玩笑的成分，又不是疯了，明知道录着呢还情绪如此外露，明显这就是熟悉的环境下跟一群熟悉的人呆在一起比较放飞自我了。多考古一下，肖战一般在一个新环境下过了认生的阶段就会非常放的开，就像是参加综艺常驻嘉宾和飞行嘉宾一样，我们的歌录制过了中段后明显是一期比一期活跃，开心到要飞起的感觉，让粉丝收获了无数表情包。明侦里的表现就更多的是严谨低调默默做事。&lt;/p&gt;&lt;p&gt;追星还是建议自己亲自考古，要不要继续喜欢由自己去判断，玻璃心和立场不坚定的真的别喜欢太红的人，不然每天心都会很累。&lt;/p&gt;</textarea>
#            <div class="zh-summary summary clearfix">
#             看了一下视频来源，这不是著名的已经疯魔了的肖战黑吗？你朋友给你发这个视频的时候应该没告诉过你这个人的事迹吧，最著名的就是开直播在线诅咒肖战，是诅咒哦，涉及生命的那种，造谣要黑肖战，P图也要黑肖战，就是一个没有底线的，一会儿威胁肖战告她她就…
#             <a class="toggle-expand" href="/question/369739953/answer/999627265">
#              显示全部
#             </a>
#            </div>
#            <p class="visible-expanded">
#             <a class="answer-date-link meta-item" href="/question/369739953/answer/999627265" itemprop="url" target="_blank">
#              发布于 2020-02-05
#             </a>
#            </p>
#           </div>
#           <div class="zm-item-meta answer-actions clearfix js-contentActions">
#            <div class="zm-meta-panel">
#             <a class="meta-item votenum-mobile zm-item-vote-count js-openVoteDialog" href="#">
#              <span data-bind-votecount="">
#               147
#              </span>
#              <i class="arrow zg-icon">
#              </i>
#             </a>
#             <div class="zm-votebar">
#              <button class="up">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="count">
#                147
#               </span>
#               <span class="label sr-only">
#                赞同
#               </span>
#              </button>
#              <button class="down">
#               <i class="icon vote-arrow">
#               </i>
#               <span class="label sr-only">
#                反对
#               </span>
#              </button>
#             </div>
#             <a class="follow-link zg-follow meta-item" data-follow="q:link" href="javascript:;" id="sfb-44441851">
#              <i class="z-icon-follow">
#              </i>
#              关注问题
#             </a>
#             <a class="meta-item toggle-comment js-toggleCommentBox" href="#" name="addcomment">
#              <i class="z-icon-comment">
#              </i>
#              8 条评论
#             </a>
#             <a class="meta-item zu-autohide js-thank" data-thanked="false" href="#">
#              <i class="z-icon-thank">
#              </i>
#              感谢
#             </a>
#             <span class="phone-actions">
#              <a class="menubutton more-actions meta-item zu-autohide" href="#">
#               <i class="zg-icon zg-icon-ellipsis-mobi">
#               </i>
#               <span class="hide-text">
#                更多
#               </span>
#              </a>
#              <div class="menu goog-menu goog-menu-vertical zh-answer-more-actions" style="display:none">
#               <div class="goog-menuitem js-share">
#                分享
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-collect">
#                收藏
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-noHelp">
#                没有帮助
#               </div>
#               <div class="goog-menuseparator">
#               </div>
#               <div class="goog-menuitem js-report">
#                举报
#               </div>
#              </div>
#             </span>
#             <meta content="1" name="copyrightStatus"/>
#             <meta content="" name="disableCopyAvatar"/>
#             <span class="zg-bull">
#              •
#             </span>
#             <a class="meta-item copyright" href="/terms#sec-licence-1" target="_blank">
#              作者保留权利
#             </a>
#             <button class="meta-item item-collapse js-collapse">
#              <i class="z-icon-fold">
#              </i>
#              收起
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="zu-main-sidebar" data-za-module="RightSideBar">
#     <div class="shameimaru-placeholder" data-loc="explore_up" data-params="{}">
#     </div>
#     <div class="zm-side-section explore-side-section explore-side-section-roundtable">
#      <div class="zm-side-section-inner">
#       <div class="section-title">
#        <a class="zg-link-gray zg-right" data-za-a="visit_roundtable_home" data-za-c="view_roundtable" data-za-l="explore_sidebar_trending_roundtable_more" href="/roundtable">
#         更多圆桌 »
#        </a>
#        <h3>
#         热门圆桌
#        </h3>
#       </div>
#       <ul class="list hot-roundtables">
#        <li class="clearfix">
#         <a class="avatar-link" href="/roundtable/psymask" target="_blank">
#          <img alt="Path" class="avatar 40" src="https://pic3.zhimg.com/v2-f402598fec30d5d9f6bed30a76f19cfd_m.jpg"/>
#         </a>
#         <div class="content">
#          <span class="status zg-right zg-gray-normal">
#           还有 1 天开始
#          </span>
#          <a data-hovercard="r$t$psymask" href="/roundtable/psymask" target="_blank">
#           送你一副心理口罩
#          </a>
#          <div class="meta">
#           <span>
#            83 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            6 个问题
#           </span>
#          </div>
#         </div>
#        </li>
#        <li class="clearfix">
#         <a class="avatar-link" href="/roundtable/yuejizhinan" target="_blank">
#          <img alt="Path" class="avatar 40" src="https://pic1.zhimg.com/v2-606200111bf4188f2f7bf53405155bab_m.jpg"/>
#         </a>
#         <div class="content">
#          <span class="status zg-right zg-gray-normal">
#           还有 6 天结束
#          </span>
#          <a data-hovercard="r$t$yuejizhinan" href="/roundtable/yuejizhinan" target="_blank">
#           女性悦己指南
#          </a>
#          <div class="meta">
#           <span>
#            729 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            13 个问题
#           </span>
#          </div>
#         </div>
#        </li>
#        <li class="clearfix">
#         <a class="avatar-link" href="/roundtable/yiqidudonghunyinfa" target="_blank">
#          <img alt="Path" class="avatar 40" src="https://pic3.zhimg.com/v2-8774a197b9d01a9e4dd5dfb6d84511f6_m.jpg"/>
#         </a>
#         <div class="content">
#          <span class="status zg-right zg-gray-normal">
#           还有 9 天结束
#          </span>
#          <a data-hovercard="r$t$yiqidudonghunyinfa" href="/roundtable/yiqidudonghunyinfa" target="_blank">
#           一起读懂《婚姻法》
#          </a>
#          <div class="meta">
#           <span>
#            1785 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            16 个问题
#           </span>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="zm-side-section explore-side-section">
#      <div class="zm-side-section-inner">
#       <div class="section-title">
#        <a class="zg-link-gray zg-right" href="/topics">
#         更多话题 »
#        </a>
#        <h3>
#         热门话题
#        </h3>
#       </div>
#       <ul class="list hot-topics">
#        <li class="clearfix">
#         <a class="avatar-link" data-hovercard="t$b$19588303" href="/topic/19588303" target="_blank">
#          <img alt="节气" class="avatar 40" src="https://pic4.zhimg.com/ebec2d3ac_m.jpg"/>
#         </a>
#         <div class="content">
#          <a data-hovercard="t$b$19588303" href="/topic/19588303" target="_blank">
#           节气
#          </a>
#          <div class="meta">
#           <span>
#            6064 人关注
#           </span>
#          </div>
#         </div>
#         <div class="bottom">
#         </div>
#        </li>
#        <li class="clearfix">
#         <a class="avatar-link" data-hovercard="t$b$19865724" href="/topic/19865724" target="_blank">
#          <img alt="神器" class="avatar 40" src="https://pic3.zhimg.com/v2-296f1ee32553f13bb898880477871660_m.jpg"/>
#         </a>
#         <div class="content">
#          <a data-hovercard="t$b$19865724" href="/topic/19865724" target="_blank">
#           神器
#          </a>
#          <div class="meta">
#           <span>
#            31377 人关注
#           </span>
#          </div>
#         </div>
#         <div class="bottom">
#         </div>
#        </li>
#        <li class="clearfix">
#         <a class="avatar-link" data-hovercard="t$b$19559450" href="/topic/19559450" target="_blank">
#          <img alt="机器学习" class="avatar 40" src="https://pic2.zhimg.com/d3dd87a0feae0a3db82973157eee89c0_m.jpg"/>
#         </a>
#         <div class="content">
#          <a data-hovercard="t$b$19559450" href="/topic/19559450" target="_blank">
#           机器学习
#          </a>
#          <div class="meta">
#           <span>
#            1063513 人关注
#           </span>
#          </div>
#         </div>
#         <div class="bottom">
#         </div>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="zm-side-section explore-side-section">
#      <div class="zm-side-section-inner">
#       <div class="section-title">
#        <a class="zg-link-gray zg-right" data-za-a="click_trending_collections_change" data-za-c="collection" data-za-l="explore_sidebar_trending_collections_collection_name" href="javascript:;" id="js-hot-fav-switch">
#         换一换
#        </a>
#        <h3>
#         热门收藏
#        </h3>
#       </div>
#       <ul class="list hot-favlists">
#        <li>
#         <div class="content">
#          <a href="/collection/19630674" target="_blank">
#           生活常识
#          </a>
#          <div class="meta">
#           <span>
#            16899 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            583 条内容
#           </span>
#          </div>
#         </div>
#        </li>
#        <li>
#         <div class="content">
#          <a href="/collection/27889117" target="_blank">
#           论一个段子手的自我修养
#          </a>
#          <div class="meta">
#           <span>
#            31072 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            363 条内容
#           </span>
#          </div>
#         </div>
#        </li>
#        <li>
#         <div class="content">
#          <a href="/collection/137714956" target="_blank">
#           .
#          </a>
#          <div class="meta">
#           <span>
#            997 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            383 条内容
#           </span>
#          </div>
#         </div>
#        </li>
#        <li>
#         <div class="content">
#          <a href="/collection/26458188" target="_blank">
#           捞出来的精华知识和经验
#          </a>
#          <div class="meta">
#           <span>
#            21346 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            1248 条内容
#           </span>
#          </div>
#         </div>
#        </li>
#        <li>
#         <div class="content">
#          <a href="/collection/21827129" target="_blank">
#           都是好东西
#          </a>
#          <div class="meta">
#           <span>
#            5785 人关注
#           </span>
#           <span class="zg-bull">
#            •
#           </span>
#           <span>
#            26631 条内容
#           </span>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="shameimaru-placeholder" data-loc="explore_down" data-params="{}">
#     </div>
#     <div class="zh-footer" id="zh-footer">
#      <div class="content zg-wrap clearfix">
#       <ul>
#        <li>
#         <a href="https://liukanshan.zhihu.com" target="_blank">
#          刘看山
#         </a>
#        </li>
#        <li>
#         <a href="/app" target="_blank">
#          移动应用
#         </a>
#        </li>
#        <li>
#         <a href="/careers">
#          加入知乎
#         </a>
#        </li>
#        <li>
#         <a href="/terms" target="_blank">
#          知乎协议
#         </a>
#        </li>
#        <li>
#         <a href="/jubao" target="_blank">
#          举报投诉
#         </a>
#        </li>
#        <li>
#         <a href="/term/privacy" target="_blank">
#          隐私政策
#         </a>
#        </li>
#        <li>
#         <a href="/contact">
#          联系我们
#         </a>
#        </li>
#       </ul>
#       <span class="copy">
#        © 2020 知乎
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script class="json-inline" data-name="guiders2" type="text/json">
#    {}
#   </script>
#   <script class="unblock-dialog-template" type="text/template">
#    <div>
# 你的帐号由于存在异常⾏为暂时被限制使⽤。如需恢复，请
# <a target="_blank" href="/account/unblock">解封帐号</a>
# </div>
#   </script>
#   <script class="json-inline" data-name="current_user" type="text/json">
#    ["","","","-1","",0,0]
#   </script>
#   <script class="json-inline" data-name="front_web_config" type="text/json">
#    {"realname_win_config":{"timestamp":1501344000,"tip":"\u5e94\u56fd\u5bb6\u6cd5\u89c4\u5bf9\u4e8e\u5e10\u53f7\u5b9e\u540d\u7684\u8981\u6c42\uff0c\u8fdb\u884c\u4e0b\u4e00\u6b65\u64cd\u4f5c\u524d\uff0c\u9700\u8981\u5148\u5b8c\u6210\u624b\u673a\u7ed1\u5b9a\u3002","continue":0,"continue_time":3600,"skip_ut_verification":0}}
#   </script>
#   <script class="json-inline" data-name="user_status" type="text/json">
#    [null,{"message":"\u60a8\u7684\u5e10\u53f7\u7531\u4e8e\u5b58\u5728\u5f02\u5e38\u884c\u4e3a\u6682\u65f6\u88ab\u77e5\u4e4e\u53cd\u4f5c\u5f0a\u7cfb\u7edf\u9650\u5236\u4f7f\u7528","by_antispam":true},false]
#   </script>
#   <script class="json-inline" data-name="env" type="text/json">
#    ["zhihu.com","comet.zhihu.com",true,null,false,false]
#   </script>
#   <script class="json-inline" data-name="permissions" type="text/json">
#    []
#   </script>
#   <script class="json-inline" data-name="ga_vars" type="text/json">
#    {"user_created":0,"now":1583338132000,"abtest_mask":"------------------------------","user_attr":[0,1,0,"-","-"],"user_hash":0}
#   </script>
#   <script class="json-inline" data-name="ra-urls" type="text/json">
#    {"Copyright":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/Copyright.773358e5.js","PayUIApp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/PayUIApp.36707672.js","CouponApp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/CouponApp.1f64e458.js","PaymentApp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/PaymentApp.a5a8951a.js","Community":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/Community.69520f6b.js","Report":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/Report.1ada2230.js","OrgOpHelp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/OrgOpHelp.9e284cd9.js","common":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/common.8eaa69f7.js","BalanceApp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/BalanceApp.1e4cdac8.js","AnswerWarrant":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/AnswerWarrant.a94bf518.js","CommentApp":"https:\/\/static.zhihu.com\/static\/revved\/-\/apps\/CommentApp.275ffa2a.js"}
#   </script>
#   <script src="https://static.zhihu.com/static/revved/-/js/vendor.cb14a042.js">
#   </script>
#   <script src="https://static.zhihu.com/static/revved/-/js/closure/base.32585258.js">
#   </script>
#   <script src="https://static.zhihu.com/static/revved/-/js/closure/common.8704d407.js">
#   </script>
#   <script async="" src="https://static.zhihu.com/static/revved/-/js/closure/richtexteditor.a43b5426.js">
#   </script>
#   <script src="https://static.zhihu.com/static/revved/-/js/closure/page-main.667c4a1b.js">
#   </script>
#   <meta content="ZH.entryExplore" data-module-id="page-main" name="entry"/>
#   <script type="text/zscript" znonce="1e11f9fbd76f425f9603b596e958ba00">
#   </script>
#   <input name="_xsrf" type="hidden" value="4e82b3da0b9cdbd9a9564001edb12af8"/>
#  </body>
# </html>

# %% [markdown]
# ### 為什麼要使用 BeatifulSoup 處理?
#
# -使用BeautifulSoup處理的好處是，他的資料型態不再是str
#
# -而是轉為可以被BeautifulSoup所剖析的"bs4.BeautifulSoup"型態
#
# -且BeautifulSoup中的不同語法可以更方便地整理、抽取我們所需要的資料

# %% [markdown]
# ### 處理後的型態是什麼？

# %%
print('「Dcard」處理後的型態為:',type(soup))
print('「知乎」處理後的型態為:',type(soup2))
# Out:
# 「Dcard」處理後的型態為: <class 'bs4.BeautifulSoup'>
# 「知乎」處理後的型態為: <class 'bs4.BeautifulSoup'>

# %% [markdown]
# # =================================

# %% [markdown]
# ## 3.觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'


r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# # 解決方法:

# %%
#因為該網站SERVER會防止爬蟲行為,
#所以加上headers中的user-agent假裝是一般網頁瀏覽者就沒事了

url = 'https://www.zhihu.com/explore'

headers = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36'}

ress = requests.get(url,headers=headers)

ress.encoding = 'utf-8'
print(ress.text[0:6000])
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-ZA-Experiment" content="default:None">
# <title>发现 - 知乎</title>
#
# <meta name="apple-itunes-app" content="app-id=432274380, app-argument=zhihu://explore">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>
# <meta http-equiv="mobile-agent" content="format=html5;url=https://www.zhihu.com/explore">
# <meta id="znonce" name="znonce" content="3d1378e3510f4496a7ca8cc0562caa00">
#
#
#
# <link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-152.87c020b9.png" sizes="152x152">
# <link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-120.496c913b.png" sizes="120x120">
# <link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-76.dcf79352.png" sizes="76x76">
# <link rel="apple-touch-icon" href="https://static.zhihu.com/static/revved/img/ios/touch-icon-60.9911cffb.png" sizes="60x60">
#
#
# <link rel="shortcut icon" href="https://static.zhihu.com/static/favicon.ico" type="image/x-icon">
#
# <link rel="search" type="application/opensearchdescription+xml" href="https://static.zhihu.com/static/search.xml" title="知乎" />
#
#
# <link rel="stylesheet" href="https://static.zhihu.com/static/revved/-/css/m.7c4d48ad.css">
#
# <meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" />
#
#
#
# <!--[if lt IE 9]>
# <script src="https://static.zhihu.com/static/components/respond/dest/respond.min.js"></script>
# <link href="https://static.zhihu.com/static/components/respond/cross-domain/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# <link href="/static/components/respond/cross-domain/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
# <script src="/static/components/respond/cross-domain/respond.proxy.js"></script>
# <![endif]-->
# <script src="https://static.zhihu.com/static/revved/-/js/instant.35b468b8.js"></script>
#
# </head>
#
# <body class="zhi page-explore">
#
#
#
#
# <div role="navigation" class="zu-top" data-za-module="TopNavBar">
# <div class="zg-wrap modal-shifting clearfix" id="zh-top-inner">
# <a href="/" class="zu-top-link-logo" id="zh-top-link-logo" data-za-c="view_home" data-za-a="visit_home" data-za-l="top_navigation_zhihu_logo">知乎</a>
#
#
#
# <ul class="topnav-noauth clearfix">
#
# <li>
# <span class="top-btn-inner-shdw"></span><span class="top-btn-sep"></span>
# </li>
# <li>
# <a href="javascript:;" class="js-signup-noauth-mobile">
# <span class="top-btn-inner-shdw left"></span>
# 注册
# <span class="top-btn-inner-shdw right"></span>
# </a>
# </li>
# <li>
# <span class="top-btn-sep"></span>
# </li>
# <li>
# <a href="javascript:;" class="js-signin-noauth-mobile">
# <span class="top-btn-inner-shdw left"></span>
# 登录
# <span class="top-btn-inner-shdw right"></span>
# </a>
# </li>
#
#
# <li>
#
# <span class="top-btn-sep"></span>
#
# </li>
# <li>
# <a href="#" id="js-openInApp">
# <span class="top-btn-inner-shdw left"></span>
# <i class="zg-icon zg-icon-cell"></i>打开 App
# </a>
# </li>
#
# </ul>
#
#
#
#
#
#
# </div>
# </div>
#
#
# <div class="zu-global-notify" id="zh-global-message" style="display:none">
# <div class="zg-wrap">
# <div class="zu-global-nitify-inner">
# <a class="zu-global-notify-close" href="javascript:;" title="关闭" name="close">x</a>
# <span class="zu-global-notify-icon"></span>
# <span class="zu-global-notify-msg"></span>
# </div>
# </div>
# </div>
#
#
#
#
# <div class="zg-wrap zu-main clearfix "  role="main">
# <div class="zu-main-content">
# <div class="zu-main-content-inner">
#
#
#
#
#
# <div id="zh-recommend">
# <div id="zh-recommend-title" class="page-title">
# <i class="zg-icon zg-icon-feedlist"></i>
# <span>编辑推荐</span>
# <a href="/explore/recommendations" class="zg-link-gray zg-right" data-za-c="explore" data-za-a="visit_explore_recommendations" data-za-l="editor_recommendations_more"><span>更多推荐 &raquo;</span></a>
# </div>
# <div id="zh-recommend-list">
#
#
# <div class="top-recommend-feed feed-item">
# <h2><a target='_blank' class="post-link" href="https://zhuanlan.zhihu.com/p/109901092" data-za-element-name="Title">85点以上gal部分实体收录(4)</a></h2>
# <div class="avatar">
# <a title="橘子皮"
# data-hovercard="p$t$cheng-zi-pi-33-6"
# class="zm-item-link-avatar"
# target="_blank"
# href="/people/cheng-zi-pi-33-6">
# <img src="https://pic2.zhimg.com/v2-488bb7ab6cecfad52cd43d164ee80484_m.jpg" class="zm-item-img-avatar">
# </a>
# </div>
# <div class="feed-main">
# <div class="author-info">
# <span class="author-link-line">
# <a class="name author-link"
# href="/people/cheng-zi-pi-33-6"
# data-hovercard="p$t$cheng-zi-pi-33-6"
# >橘子皮</a></span><span class="bio">动漫，galgame，推理，文学</span>
# </div>
# <div class="post-content">
# <textarea hidden class="content">&lt;p&gt;自2月份中旬正式复工以来，抽空写了85点以上gal部分实体收录(4)。直至(4)为止我一共展示了40部85点及以上galgame的游戏本体，并简要发表了对每部作品的大致感受。哎，没想到这个坑已经填一半了。在(4.5)我将把我没玩过的或者我难以评价的作品做一个汇总，可能(4.5)会超过十部gal。剩下的85点作品评价由于凑不齐10部，也有因为客观因素没有购入的原因，会无限期停更。&lt;/p&gt;&lt;p&gt;届时应该会开两个新坑，一是galgame原声ost收录(个人向)，二是对于喜好的作品尝试写万字评价(这个坑其实有预兆，第一篇就是樱之诗)。&lt;/p&gt;&lt;p&gt;总感觉没必要把我想写的东西说的那么详细，毕竟我也不是那么勤快的人。&lt;/p&gt;&lt;figure data-size=&quot;normal&quot;&gt;&lt;img src=&quot;https://pic1.zhimg.com/v2-bd0534289b5a451dd5fbdc6505e1c478_b.jpg&quot; data-rawwidth=&quot;2048&quot; data-rawheight=&quot;1535&quot; data-size=&quot;normal&quot; class=&quot;origin_image zh-lightbox-thumb&quot; width=&quot;2048&quot; data-original=&quot;https://pic1.zhimg.com/v2-bd0534289b5a451dd5fbdc6505e1c478_r.jpg&quot;/&gt;&lt;/figure&gt;&lt;p&gt;&lt;b&gt;31.phantom&lt;/b&gt;&lt;/p&gt;&lt;p&gt;会社:nitro+&lt;/p&gt;&lt;p&gt;脚本:虚渊玄&lt;/p&gt;&lt;p&gt;发售时间:2000/09/05&lt;/p&gt;&lt;p&gt;中央值:87&lt;/p&gt;&lt;p&gt;我毫不怀疑老虚借鉴了这个杀手不太冷里面杀手莱昂培养萝莉这段情节以及喋血双雄最后的教堂对决，模仿痕迹比较明显，phantom的故事或多或少都有港片的影子，组织、世仇、暗杀、包括深陷爱情与家族矛盾的黑道大小姐。从接纳组织，到最后背弃组织，为自己而战，这部当时据说领先业界十年的作品，其实一环一环看下来，故事的情节并不那么新鲜。老虚比较擅长杂和电影小说的情节来讲自己的故事，直白点说就是喜欢抄设定，集各家之所长，这就使得phantom即便现在看来依旧有非常耐人寻味的点。&lt;/p&gt;&lt;p&gt;与大多组织培养的杀手不同，phantom里的三位核心杀手并不是充当背景板的角色，他们的羁绊颇深，ein是玲二的师父，而玲二跟凯尔有一段孽缘。我不太理解凯尔恨玲二的理由，他们都曾彼此深爱过对方，动过真情，两年前住所的爆炸是一场误解，所以在玲二举枪杀死凯尔的那一刻后，玲二说&amp;#34;我们只是有一瞬间错过了对方而已&amp;#34;。这是我认为phantom震撼我
